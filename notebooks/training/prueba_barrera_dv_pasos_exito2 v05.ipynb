# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

import sys
from pathlib import Path
import importlib
import numpy as np
import torch
import matplotlib.pyplot as plt

# Asegura que el ROOT esté en sys.path para poder importar src/*
ROOT = Path().resolve()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

print("ROOT:", ROOT)
print("Python:", sys.version)
print("Torch:", torch.__version__)
# Out:
# ROOT: C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025
# Python: 3.11.13 | packaged by conda-forge | (main, Jun  4 2025, 14:39:58) [MSC v.1943 64 bit (AMD64)]
# Torch: 2.5.1+cpu

# %%
import importlib

# (opcional) recarga módulos si estás editando código en caliente
import src.trainer.schrodinger_train as sch_train
import src.nn.DVPDESolver as dv_solver_mod
import src.problems.schrodinger as sch_prob

importlib.reload(sch_train)
importlib.reload(dv_solver_mod)
importlib.reload(sch_prob)

# ===== Imports correctos =====
from src.trainer.schrodinger_train import train
from src.nn.DVPDESolver import DVPDESolver

from src.problems.schrodinger import build_eq_params, sanity_check
from src.problems.schrodinger.problem import build_problem

from src.utils.logger import Logging

print("Imports OK.")
# Out:
# Imports OK.

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
dtype  = torch.float32   # para pruebas rápidas
print("device:", device, "| dtype:", dtype)

# ====== PARAMETROS DEL PROBLEMA: BARRERA ======
eq_params = build_eq_params(
    "barrier",
    L=1.0,
    T=0.2,
    n_level=1,      # ojo: en barrier es índice 0-based en tu exact numérica
    mass=1.0,
    hbar=1.0,
    # barrera
    V0=5.0,
    barrier_width=0.2,
    x_center=0.6,
    # malla para exact numérico
    num_grid=400,
)

print("eq_params:", eq_params)
# Out:
# device: cpu | dtype: torch.float32
# eq_params: {'example': 'barrier', 'L': 1.0, 'T': 0.2, 'mass': 1.0, 'hbar': 1.0, 'n_level': 1, 'x_min': 0.0, 'x_max': 1.0, 'omega': 1.0, 'V0': 5.0, 'barrier_width': 0.2, 'x_center': 0.6, 'num_grid': 400}

# %%
from pathlib import Path
dv_file = ROOT / "src" / "nn" / "DVPDESolver.py"
txt = dv_file.read_text(encoding="utf-8", errors="ignore")

# buscamos el patrón correcto de rotación: re2 = re*c + im*s ; im2 = im*c - re*s
ok1 = ("re2 = re * c + im * s" in txt) or ("re2 = re*c + im*s" in txt)
ok2 = ("im2 = im * c - re * s" in txt) or ("im2 = im*c - re*s" in txt)

print("DVPDESolver.py:", dv_file)
print("Global-phase sign OK?:", ok1 and ok2)

if not (ok1 and ok2):
    print("\n⚠️  Parece que el signo NO está corregido.")
    print("    Corrige _apply_global_phase para implementar exp(-i ω t).")
# Out:
# DVPDESolver.py: C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\src\nn\DVPDESolver.py
# Global-phase sign OK?: True

# %%
def predict_psi(model, t, x):
    """Devuelve psi_pred (complejo) como tensor complejo shape [N,1]."""
    tx = torch.cat([t, x], dim=1)
    out = model(tx)
    re = out[:, 0:1]
    im = out[:, 1:2]
    return re + 1j * im

def exact_psi(problem, n_level, t, x):
    """Devuelve psi_exact (complejo) y también E."""
    re_e, im_e, E = problem["exact"](n_level, t, x)
    return (re_e + 1j * im_e), E

def density(psi):
    return (psi.real**2 + psi.imag**2)

def l2_rel(a, b, eps=1e-12):
    """L2 relativo estándar."""
    num = torch.sqrt(torch.mean(torch.abs(a - b)**2))
    den = torch.sqrt(torch.mean(torch.abs(b)**2)) + eps
    return num / den

def l2_rel_phase_invariant(psi_pred, psi_exact, eps=1e-12):
    """L2 relativo tras alinear fase global óptima alpha."""
    alpha = (torch.mean(torch.conj(psi_pred) * psi_exact) /
             (torch.mean(torch.conj(psi_pred) * psi_pred) + eps))
    psi_corr = alpha * psi_pred
    return l2_rel(psi_corr, psi_exact)

def plot_density_1d(problem, model, title="", n_pts=600):
    device_ = next(model.parameters()).device
    dtype_  = next(model.parameters()).dtype

    x = torch.linspace(problem["x_min"], problem["x_max"], n_pts, device=device_, dtype=dtype_).reshape(-1,1)

    for t_val, tag in [(0.0, "t=0"), (float(problem["T"]), f"t=T={problem['T']}")]:
        t = torch.full_like(x, t_val)
        with torch.no_grad():
            psi_p = predict_psi(model, t, x)
            psi_e, _ = exact_psi(problem, problem["n_level"], t, x)
            rho_p = density(psi_p).detach().cpu().numpy().flatten()
            rho_e = density(psi_e).detach().cpu().numpy().flatten()
            x_np  = x.detach().cpu().numpy().flatten()

        plt.figure(figsize=(7.2,3.4))
        plt.plot(x_np, rho_e, label="Exact")
        plt.plot(x_np, rho_p, "--", label="Pred")
        plt.title(f"{title} |psi(x,{tag})|^2")
        plt.xlabel("x")
        plt.ylabel("|psi|^2")
        plt.legend()
        plt.tight_layout()
        plt.show()

def quick_metrics(problem, model, t_val=None, n_pts=400):
    """Imprime L2 complejo, L2 fase-invariante y L2 densidad."""
    device_ = next(model.parameters()).device
    dtype_  = next(model.parameters()).dtype

    x = torch.linspace(problem["x_min"], problem["x_max"], n_pts, device=device_, dtype=dtype_).reshape(-1,1)
    if t_val is None:
        t_val = float(problem["T"])
    t = torch.full_like(x, float(t_val))

    with torch.no_grad():
        psi_p = predict_psi(model, t, x)
        psi_e, E = exact_psi(problem, problem["n_level"], t, x)
        rho_p = density(psi_p)
        rho_e = density(psi_e)

        l2_c   = l2_rel(psi_p, psi_e).item()
        l2_ph  = l2_rel_phase_invariant(psi_p, psi_e).item()
        l2_rho = l2_rel(rho_p, rho_e).item()

    print(f"[Metrics @ t={t_val}] L2_complex={l2_c:.4f} | L2_phase={l2_ph:.4f} | L2_density={l2_rho:.4f}")
    return E

# %%
problem = build_problem(eq_params, device=device, dtype=dtype)

args_stage1 = {
    "eq_params": eq_params,
    "device": device,
    "dtype": dtype,
    "problem": "schrodinger",

    # training (rápido)
    "epochs": 450,
    "warmup_epochs": 0,
    "lr": 1e-3,
    "batch_size": 64,
    "print_every": 10,

    # losses: SOLO IC (PDE apagado)
    "w_pde": 0.0,
    "w_pde_i": 1.0,     # irrelevante si w_pde=0
    "w_ic": 800.0,
    "w_ic_i": 5.0,
    "w_norm": 0.0,

    # BC dura
    "hard_bc": True,
    "w_bc": 0.0,
    "hard_bc_power": 1.0,
    "hard_bc_scale": 4.0,

    # IC sampling / val
    "ic_grid": True,
    "N_norm": 400,
    "N_val": 400,

    # DV circuit
    "num_qubits": 4,
    "num_quantum_layers": 2,
    "shots": None,
    "noise": False,
    "encoding": "angle",
    "q_ansatz": "sim_circ_19",

    # hybrid net
    "classic_network": [2, 64, 64, 2],

    # performance / métricas
    "pde_chunk_size": 64,
    "l2_every": 10,

    # fase global (se mantiene igual en ambas etapas)
    "global_phase": True,
    "global_phase_spatial_only": True,
    "global_phase_omega_init": 5.0,
    "use_lbfgs": False,

    # estabilidad de ángulos (si tu DVPDESolver lo soporta)
    "angle_squash": True,
}

model = DVPDESolver(args_stage1, logger=Logging(ROOT / "results"), device=device).to(device)
print("Model dtype:", next(model.parameters()).dtype)
# Out:
# Model dtype: torch.float32

# %%
# Manteniendo tus tamaños rápidos:
train(model, N_f=512, N_b=0, N_0=1000)

print("\nEtapa 1 (IC-only) terminada.")
plot_density_1d(problem, model, title="Etapa 1")
E = quick_metrics(problem, model, t_val=0.0)
# Out:
# INFO:src.utils.logger:The circuit used in the study:
# INFO:src.utils.logger:It: 1, Loss: 9.250e+02, Loss_res: 1.667e+00,  Loss_bcs: 0.000e+00, Loss_ut_ics: 1.156e+00, Loss_norm: 7.842e-01, Loss_gauge: 0.000e+00, w_pde: 0.00e+00, L^2_error: 1.043e+00, lr: 1.000e-03, Time: 2.12e+00
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 10, Loss: 7.953e+02, Loss_res: 2.329e-01,  Loss_bcs: 0.000e+00, Loss_ut_ics: 9.941e-01, Loss_norm: 9.772e-01, Loss_gauge: 0.000e+00, w_pde: 0.00e+00, L^2_error: 1.012e+00, lr: 1.000e-03, Time: 1.96e+01
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 20, Loss: 7.887e+02, Loss_res: 2.625e-02,  Loss_bcs: 0.000e+00, Loss_ut_ics: 9.858e-01, Loss_norm: 9.995e-01, Loss_gauge: 0.000e+00, w_pde: 0.00e+00, L^2_error: 1.008e+00, lr: 1.000e-03, Time: 3.50e+01
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 30, Loss: 7.689e+02, Loss_res: 2.358e-01,  Loss_bcs: 0.000e+00, Loss_ut_ics: 9.611e-01, Loss_norm: 9.904e-01, Loss_gauge: 0.000e+00, w_pde: 0.00e+00, L^2_error: 1.027e+00, lr: 1.000e-03, Time: 4.99e+01
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 40, Loss: 7.345e+02, Loss_res: 1.051e+00,  Loss_bcs: 0.000e+00, Loss_ut_ics: 9.182e-01, Loss_norm: 9.633e-01, Loss_gauge: 0.000e+00, w_pde: 0.00e+00, L^2_error: 1.062e+00, lr: 1.000e-03, Time: 6.50e+01
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 50, Loss: 6.524e+02, Loss_res: 2.958e+00,  Loss_bcs: 0.000e+00, Loss_ut_ics: 8.155e-01, Loss_norm: 9.578e-01, Loss_gauge: 0.000e+00, w_pde: 0.00e+00, L^2_error: 1.117e+00, lr: 1.000e-03, Time: 8.44e+01
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 60, Loss: 4.868e+02, Loss_res: 1.315e+01,  Loss_bcs: 0.000e+00, Loss_ut_ics: 6.085e-01, Loss_norm: 8.882e-01, Loss_gauge: 0.000e+00, w_pde: 0.00e+00, L^2_error: 1.246e+00, lr: 1.000e-03, Time: 1.00e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 70, Loss: 2.532e+02, Loss_res: 5.560e+01,  Loss_bcs: 0.000e+00, Loss_ut_ics: 3.164e-01, Loss_norm: 6.479e-01, Loss_gauge: 0.000e+00, w_pde: 0.00e+00, L^2_error: 1.466e+00, lr: 1.000e-03, Time: 1.16e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 80, Loss: 6.247e+01, Loss_res: 1.774e+02,  Loss_bcs: 0.000e+00, Loss_ut_ics: 7.809e-02, Loss_norm: 2.144e-01, Loss_gauge: 0.000e+00, w_pde: 0.00e+00, L^2_error: 1.760e+00, lr: 1.000e-03, Time: 1.31e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 90, Loss: 9.235e+00, Loss_res: 3.703e+02,  Loss_bcs: 0.000e+00, Loss_ut_ics: 1.154e-02, Loss_norm: 9.895e-04, Loss_gauge: 0.000e+00, w_pde: 0.00e+00, L^2_error: 1.997e+00, lr: 1.000e-03, Time: 1.46e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 100, Loss: 7.347e+00, Loss_res: 4.169e+02,  Loss_bcs: 0.000e+00, Loss_ut_ics: 9.184e-03, Loss_norm: 4.105e-03, Loss_gauge: 0.000e+00, w_pde: 0.00e+00, L^2_error: 2.020e+00, lr: 1.000e-03, Time: 1.61e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 110, Loss: 4.095e+00, Loss_res: 3.221e+02,  Loss_bcs: 0.000e+00, Loss_ut_ics: 5.118e-03, Loss_norm: 2.987e-03, Loss_gauge: 0.000e+00, w_pde: 0.00e+00, L^2_error: 1.977e+00, lr: 1.000e-03, Time: 1.76e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 120, Loss: 2.564e+00, Loss_res: 3.580e+02,  Loss_bcs: 0.000e+00, Loss_ut_ics: 3.206e-03, Loss_norm: 2.389e-04, Loss_gauge: 0.000e+00, w_pde: 0.00e+00, L^2_error: 2.005e+00, lr: 1.000e-03, Time: 1.90e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 130, Loss: 1.839e+00, Loss_res: 3.178e+02,  Loss_bcs: 0.000e+00, Loss_ut_ics: 2.298e-03, Loss_norm: 2.413e-04, Loss_gauge: 0.000e+00, w_pde: 0.00e+00, L^2_error: 1.991e+00, lr: 1.000e-03, Time: 2.05e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 140, Loss: 1.352e+00, Loss_res: 3.078e+02,  Loss_bcs: 0.000e+00, Loss_ut_ics: 1.690e-03, Loss_norm: 5.965e-05, Loss_gauge: 0.000e+00, w_pde: 0.00e+00, L^2_error: 1.996e+00, lr: 1.000e-03, Time: 2.20e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 150, Loss: 1.059e+00, Loss_res: 3.101e+02,  Loss_bcs: 0.000e+00, Loss_ut_ics: 1.324e-03, Loss_norm: 4.226e-06, Loss_gauge: 0.000e+00, w_pde: 0.00e+00, L^2_error: 1.998e+00, lr: 1.000e-03, Time: 2.35e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 160, Loss: 8.708e-01, Loss_res: 3.045e+02,  Loss_bcs: 0.000e+00, Loss_ut_ics: 1.089e-03, Loss_norm: 6.259e-05, Loss_gauge: 0.000e+00, w_pde: 0.00e+00, L^2_error: 1.996e+00, lr: 1.000e-03, Time: 2.50e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 170, Loss: 7.360e-01, Loss_res: 3.049e+02,  Loss_bcs: 0.000e+00, Loss_ut_ics: 9.200e-04, Loss_norm: 6.545e-06, Loss_gauge: 0.000e+00, w_pde: 0.00e+00, L^2_error: 1.998e+00, lr: 1.000e-03, Time: 2.65e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 180, Loss: 6.391e-01, Loss_res: 2.907e+02,  Loss_bcs: 0.000e+00, Loss_ut_ics: 7.989e-04, Loss_norm: 2.183e-05, Loss_gauge: 0.000e+00, w_pde: 0.00e+00, L^2_error: 1.997e+00, lr: 1.000e-03, Time: 2.79e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 190, Loss: 5.684e-01, Loss_res: 2.741e+02,  Loss_bcs: 0.000e+00, Loss_ut_ics: 7.105e-04, Loss_norm: 1.396e-05, Loss_gauge: 0.000e+00, w_pde: 0.00e+00, L^2_error: 1.998e+00, lr: 1.000e-03, Time: 2.94e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 200, Loss: 5.152e-01, Loss_res: 2.768e+02,  Loss_bcs: 0.000e+00, Loss_ut_ics: 6.440e-04, Loss_norm: 1.047e-05, Loss_gauge: 0.000e+00, w_pde: 0.00e+00, L^2_error: 1.998e+00, lr: 1.000e-03, Time: 3.09e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 210, Loss: 4.744e-01, Loss_res: 2.982e+02,  Loss_bcs: 0.000e+00, Loss_ut_ics: 5.930e-04, Loss_norm: 1.113e-05, Loss_gauge: 0.000e+00, w_pde: 0.00e+00, L^2_error: 1.998e+00, lr: 1.000e-03, Time: 3.23e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 220, Loss: 4.426e-01, Loss_res: 2.771e+02,  Loss_bcs: 0.000e+00, Loss_ut_ics: 5.532e-04, Loss_norm: 8.036e-06, Loss_gauge: 0.000e+00, w_pde: 0.00e+00, L^2_error: 1.998e+00, lr: 1.000e-03, Time: 3.38e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 230, Loss: 4.175e-01, Loss_res: 2.857e+02,  Loss_bcs: 0.000e+00, Loss_ut_ics: 5.219e-04, Loss_norm: 7.225e-06, Loss_gauge: 0.000e+00, w_pde: 0.00e+00, L^2_error: 1.998e+00, lr: 1.000e-03, Time: 3.53e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 240, Loss: 3.976e-01, Loss_res: 2.663e+02,  Loss_bcs: 0.000e+00, Loss_ut_ics: 4.970e-04, Loss_norm: 6.317e-06, Loss_gauge: 0.000e+00, w_pde: 0.00e+00, L^2_error: 1.998e+00, lr: 1.000e-03, Time: 3.67e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 250, Loss: 3.816e-01, Loss_res: 2.641e+02,  Loss_bcs: 0.000e+00, Loss_ut_ics: 4.771e-04, Loss_norm: 5.194e-06, Loss_gauge: 0.000e+00, w_pde: 0.00e+00, L^2_error: 1.999e+00, lr: 1.000e-03, Time: 3.82e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 260, Loss: 3.688e-01, Loss_res: 2.901e+02,  Loss_bcs: 0.000e+00, Loss_ut_ics: 4.609e-04, Loss_norm: 4.665e-06, Loss_gauge: 0.000e+00, w_pde: 0.00e+00, L^2_error: 1.999e+00, lr: 1.000e-03, Time: 3.97e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 270, Loss: 3.583e-01, Loss_res: 2.853e+02,  Loss_bcs: 0.000e+00, Loss_ut_ics: 4.478e-04, Loss_norm: 3.964e-06, Loss_gauge: 0.000e+00, w_pde: 0.00e+00, L^2_error: 1.999e+00, lr: 1.000e-03, Time: 4.12e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 280, Loss: 3.497e-01, Loss_res: 2.752e+02,  Loss_bcs: 0.000e+00, Loss_ut_ics: 4.371e-04, Loss_norm: 3.462e-06, Loss_gauge: 0.000e+00, w_pde: 0.00e+00, L^2_error: 1.999e+00, lr: 1.000e-03, Time: 4.27e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 290, Loss: 3.426e-01, Loss_res: 2.740e+02,  Loss_bcs: 0.000e+00, Loss_ut_ics: 4.282e-04, Loss_norm: 3.029e-06, Loss_gauge: 0.000e+00, w_pde: 0.00e+00, L^2_error: 1.999e+00, lr: 1.000e-03, Time: 4.42e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 300, Loss: 3.367e-01, Loss_res: 2.743e+02,  Loss_bcs: 0.000e+00, Loss_ut_ics: 4.209e-04, Loss_norm: 2.633e-06, Loss_gauge: 0.000e+00, w_pde: 0.00e+00, L^2_error: 1.999e+00, lr: 1.000e-03, Time: 4.57e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 310, Loss: 3.318e-01, Loss_res: 2.789e+02,  Loss_bcs: 0.000e+00, Loss_ut_ics: 4.148e-04, Loss_norm: 2.317e-06, Loss_gauge: 0.000e+00, w_pde: 0.00e+00, L^2_error: 1.999e+00, lr: 1.000e-03, Time: 4.73e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 320, Loss: 3.277e-01, Loss_res: 2.660e+02,  Loss_bcs: 0.000e+00, Loss_ut_ics: 4.097e-04, Loss_norm: 2.033e-06, Loss_gauge: 0.000e+00, w_pde: 0.00e+00, L^2_error: 1.999e+00, lr: 1.000e-03, Time: 4.88e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 330, Loss: 3.243e-01, Loss_res: 2.573e+02,  Loss_bcs: 0.000e+00, Loss_ut_ics: 4.054e-04, Loss_norm: 1.797e-06, Loss_gauge: 0.000e+00, w_pde: 0.00e+00, L^2_error: 1.999e+00, lr: 1.000e-03, Time: 5.03e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 340, Loss: 3.214e-01, Loss_res: 2.523e+02,  Loss_bcs: 0.000e+00, Loss_ut_ics: 4.018e-04, Loss_norm: 1.590e-06, Loss_gauge: 0.000e+00, w_pde: 0.00e+00, L^2_error: 1.999e+00, lr: 1.000e-03, Time: 5.17e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 350, Loss: 3.189e-01, Loss_res: 2.768e+02,  Loss_bcs: 0.000e+00, Loss_ut_ics: 3.987e-04, Loss_norm: 1.409e-06, Loss_gauge: 0.000e+00, w_pde: 0.00e+00, L^2_error: 1.999e+00, lr: 1.000e-03, Time: 5.32e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 360, Loss: 3.168e-01, Loss_res: 2.569e+02,  Loss_bcs: 0.000e+00, Loss_ut_ics: 3.960e-04, Loss_norm: 1.258e-06, Loss_gauge: 0.000e+00, w_pde: 0.00e+00, L^2_error: 1.999e+00, lr: 1.000e-03, Time: 5.47e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 370, Loss: 3.150e-01, Loss_res: 2.654e+02,  Loss_bcs: 0.000e+00, Loss_ut_ics: 3.938e-04, Loss_norm: 1.123e-06, Loss_gauge: 0.000e+00, w_pde: 0.00e+00, L^2_error: 1.999e+00, lr: 1.000e-03, Time: 5.62e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 380, Loss: 3.135e-01, Loss_res: 2.609e+02,  Loss_bcs: 0.000e+00, Loss_ut_ics: 3.918e-04, Loss_norm: 1.008e-06, Loss_gauge: 0.000e+00, w_pde: 0.00e+00, L^2_error: 1.999e+00, lr: 1.000e-03, Time: 5.76e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 390, Loss: 3.121e-01, Loss_res: 2.589e+02,  Loss_bcs: 0.000e+00, Loss_ut_ics: 3.901e-04, Loss_norm: 9.067e-07, Loss_gauge: 0.000e+00, w_pde: 0.00e+00, L^2_error: 1.999e+00, lr: 1.000e-03, Time: 5.91e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 400, Loss: 3.109e-01, Loss_res: 2.705e+02,  Loss_bcs: 0.000e+00, Loss_ut_ics: 3.886e-04, Loss_norm: 8.198e-07, Loss_gauge: 0.000e+00, w_pde: 0.00e+00, L^2_error: 1.999e+00, lr: 1.000e-03, Time: 6.06e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 410, Loss: 3.098e-01, Loss_res: 2.594e+02,  Loss_bcs: 0.000e+00, Loss_ut_ics: 3.873e-04, Loss_norm: 7.437e-07, Loss_gauge: 0.000e+00, w_pde: 0.00e+00, L^2_error: 1.999e+00, lr: 1.000e-03, Time: 6.21e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 420, Loss: 3.089e-01, Loss_res: 2.719e+02,  Loss_bcs: 0.000e+00, Loss_ut_ics: 3.861e-04, Loss_norm: 6.776e-07, Loss_gauge: 0.000e+00, w_pde: 0.00e+00, L^2_error: 1.999e+00, lr: 1.000e-03, Time: 6.37e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 430, Loss: 3.081e-01, Loss_res: 2.669e+02,  Loss_bcs: 0.000e+00, Loss_ut_ics: 3.851e-04, Loss_norm: 6.194e-07, Loss_gauge: 0.000e+00, w_pde: 0.00e+00, L^2_error: 1.999e+00, lr: 1.000e-03, Time: 6.52e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 440, Loss: 3.073e-01, Loss_res: 2.648e+02,  Loss_bcs: 0.000e+00, Loss_ut_ics: 3.841e-04, Loss_norm: 5.689e-07, Loss_gauge: 0.000e+00, w_pde: 0.00e+00, L^2_error: 1.999e+00, lr: 1.000e-03, Time: 6.67e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 450, Loss: 3.066e-01, Loss_res: 2.719e+02,  Loss_bcs: 0.000e+00, Loss_ut_ics: 3.833e-04, Loss_norm: 5.242e-07, Loss_gauge: 0.000e+00, w_pde: 0.00e+00, L^2_error: 1.999e+00, lr: 1.000e-03, Time: 6.82e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# Etapa 1 (IC-only) terminada.
# [Metrics @ t=0.0] L2_complex=0.0195 | L2_phase=0.0195 | L2_density=0.0290

# %%
# Calcula E/hbar usando exact (en cualquier x0 sirve)
device_ = next(model.parameters()).device
dtype_  = next(model.parameters()).dtype

x0 = torch.tensor([[0.37]], device=device_, dtype=dtype_)
t0 = torch.zeros_like(x0)

with torch.no_grad():
    psi_e0, E = exact_psi(problem, problem["n_level"], t0, x0)
omega_star = float((E / problem["hbar"]).detach().cpu())

print("E =", float(E.detach().cpu()))
print("omega_star = E/hbar =", omega_star)

# set + freeze
if hasattr(model, "global_phase_omega"):
    model.global_phase_omega.data.fill_(omega_star)
    model.global_phase_omega.requires_grad_(False)
    print("✅ omega fijada y congelada.")
else:
    print("⚠️ Tu modelo no tiene global_phase_omega. Revisa DVPDESolver.")
# Out:
# E = 20.553302764892578
# omega_star = E/hbar = 20.553302764892578
# ✅ omega fijada y congelada.

# %%
# Actualiza args dentro del modelo (train() lee model.args)
model.args["epochs"] = 450
model.args["warmup_epochs"] = 100

model.args["w_pde"] = 1.0
model.args["w_pde_i"] = 1.0       # importante: NO 10
model.args["w_norm"] = 10.0

# dejamos IC igual
model.args["w_ic"] = 800.0
model.args["w_ic_i"] = 5.0

model.args["use_lbfgs"] = False
model.args["angle_squash"] = True

train(model, N_f=512, N_b=0, N_0=1000)

print("\nEtapa 2 (Physics-informed) terminada.")
plot_density_1d(problem, model, title="Etapa 2")
E = quick_metrics(problem, model, t_val=float(problem["T"]))
# Out:
# INFO:src.utils.logger:It: 1, Loss: 4.122e-01, Loss_res: 1.057e+01,  Loss_bcs: 0.000e+00, Loss_ut_ics: 3.832e-04, Loss_norm: 5.210e-07, Loss_gauge: 0.000e+00, w_pde: 1.00e-02, L^2_error: 1.195e-01, lr: 1.000e-03, Time: 1.59e+00
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 10, Loss: 4.866e+00, Loss_res: 9.114e+00,  Loss_bcs: 0.000e+00, Loss_ut_ics: 4.904e-03, Loss_norm: 3.159e-03, Loss_gauge: 0.000e+00, w_pde: 1.00e-01, L^2_error: 5.719e-02, lr: 1.000e-03, Time: 1.62e+01
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 20, Loss: 3.240e+00, Loss_res: 1.032e+01,  Loss_bcs: 0.000e+00, Loss_ut_ics: 1.470e-03, Loss_norm: 1.049e-04, Loss_gauge: 0.000e+00, w_pde: 2.00e-01, L^2_error: 4.235e-02, lr: 1.000e-03, Time: 3.13e+01
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 30, Loss: 3.407e+00, Loss_res: 9.812e+00,  Loss_bcs: 0.000e+00, Loss_ut_ics: 5.762e-04, Loss_norm: 2.965e-04, Loss_gauge: 0.000e+00, w_pde: 3.00e-01, L^2_error: 2.937e-02, lr: 1.000e-03, Time: 4.67e+01
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 40, Loss: 4.027e+00, Loss_res: 9.177e+00,  Loss_bcs: 0.000e+00, Loss_ut_ics: 4.428e-04, Loss_norm: 1.680e-04, Loss_gauge: 0.000e+00, w_pde: 4.00e-01, L^2_error: 2.436e-02, lr: 1.000e-03, Time: 6.24e+01
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 50, Loss: 4.691e+00, Loss_res: 8.630e+00,  Loss_bcs: 0.000e+00, Loss_ut_ics: 4.688e-04, Loss_norm: 1.525e-04, Loss_gauge: 0.000e+00, w_pde: 5.00e-01, L^2_error: 2.287e-02, lr: 1.000e-03, Time: 7.71e+01
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 60, Loss: 6.133e+00, Loss_res: 9.557e+00,  Loss_bcs: 0.000e+00, Loss_ut_ics: 4.927e-04, Loss_norm: 4.035e-04, Loss_gauge: 0.000e+00, w_pde: 6.00e-01, L^2_error: 2.232e-02, lr: 1.000e-03, Time: 9.20e+01
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 70, Loss: 6.817e+00, Loss_res: 9.185e+00,  Loss_bcs: 0.000e+00, Loss_ut_ics: 4.811e-04, Loss_norm: 2.745e-04, Loss_gauge: 0.000e+00, w_pde: 7.00e-01, L^2_error: 2.207e-02, lr: 1.000e-03, Time: 1.07e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 80, Loss: 7.169e+00, Loss_res: 8.454e+00,  Loss_bcs: 0.000e+00, Loss_ut_ics: 5.016e-04, Loss_norm: 4.542e-04, Loss_gauge: 0.000e+00, w_pde: 8.00e-01, L^2_error: 2.196e-02, lr: 1.000e-03, Time: 1.21e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 90, Loss: 8.251e+00, Loss_res: 8.727e+00,  Loss_bcs: 0.000e+00, Loss_ut_ics: 4.891e-04, Loss_norm: 4.494e-04, Loss_gauge: 0.000e+00, w_pde: 9.00e-01, L^2_error: 2.175e-02, lr: 1.000e-03, Time: 1.36e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 100, Loss: 8.403e+00, Loss_res: 8.026e+00,  Loss_bcs: 0.000e+00, Loss_ut_ics: 4.649e-04, Loss_norm: 5.270e-04, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 2.101e-02, lr: 1.000e-03, Time: 1.51e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 110, Loss: 8.351e+00, Loss_res: 7.857e+00,  Loss_bcs: 0.000e+00, Loss_ut_ics: 6.048e-04, Loss_norm: 9.748e-04, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 2.490e-02, lr: 1.000e-03, Time: 1.66e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 120, Loss: 8.211e+00, Loss_res: 7.801e+00,  Loss_bcs: 0.000e+00, Loss_ut_ics: 5.051e-04, Loss_norm: 6.194e-04, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 2.221e-02, lr: 1.000e-03, Time: 1.81e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 130, Loss: 7.458e+00, Loss_res: 7.156e+00,  Loss_bcs: 0.000e+00, Loss_ut_ics: 3.730e-04, Loss_norm: 3.987e-04, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 1.925e-02, lr: 1.000e-03, Time: 1.97e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 140, Loss: 7.742e+00, Loss_res: 7.365e+00,  Loss_bcs: 0.000e+00, Loss_ut_ics: 4.649e-04, Loss_norm: 5.106e-04, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 1.944e-02, lr: 1.000e-03, Time: 2.11e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 150, Loss: 7.337e+00, Loss_res: 7.076e+00,  Loss_bcs: 0.000e+00, Loss_ut_ics: 3.219e-04, Loss_norm: 3.518e-04, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 1.958e-02, lr: 1.000e-03, Time: 2.24e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 160, Loss: 6.679e+00, Loss_res: 6.382e+00,  Loss_bcs: 0.000e+00, Loss_ut_ics: 3.663e-04, Loss_norm: 3.539e-04, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 1.884e-02, lr: 1.000e-03, Time: 2.38e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 170, Loss: 6.824e+00, Loss_res: 6.577e+00,  Loss_bcs: 0.000e+00, Loss_ut_ics: 3.034e-04, Loss_norm: 3.744e-04, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 1.725e-02, lr: 1.000e-03, Time: 2.53e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 180, Loss: 6.345e+00, Loss_res: 6.112e+00,  Loss_bcs: 0.000e+00, Loss_ut_ics: 2.872e-04, Loss_norm: 3.805e-04, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 1.634e-02, lr: 1.000e-03, Time: 2.67e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 190, Loss: 5.989e+00, Loss_res: 5.612e+00,  Loss_bcs: 0.000e+00, Loss_ut_ics: 4.656e-04, Loss_norm: 4.755e-04, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 1.699e-02, lr: 1.000e-03, Time: 2.81e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 200, Loss: 6.371e+00, Loss_res: 6.008e+00,  Loss_bcs: 0.000e+00, Loss_ut_ics: 4.478e-04, Loss_norm: 5.041e-04, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 1.601e-02, lr: 1.000e-03, Time: 2.94e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 210, Loss: 6.428e+00, Loss_res: 6.064e+00,  Loss_bcs: 0.000e+00, Loss_ut_ics: 4.509e-04, Loss_norm: 4.067e-04, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 1.543e-02, lr: 1.000e-03, Time: 3.08e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 220, Loss: 5.970e+00, Loss_res: 5.662e+00,  Loss_bcs: 0.000e+00, Loss_ut_ics: 3.789e-04, Loss_norm: 4.854e-04, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 1.494e-02, lr: 1.000e-03, Time: 3.21e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 230, Loss: 6.311e+00, Loss_res: 6.045e+00,  Loss_bcs: 0.000e+00, Loss_ut_ics: 3.281e-04, Loss_norm: 3.662e-04, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 1.492e-02, lr: 1.000e-03, Time: 3.35e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 240, Loss: 5.566e+00, Loss_res: 5.386e+00,  Loss_bcs: 0.000e+00, Loss_ut_ics: 2.213e-04, Loss_norm: 2.361e-04, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 1.406e-02, lr: 1.000e-03, Time: 3.49e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 250, Loss: 5.919e+00, Loss_res: 5.760e+00,  Loss_bcs: 0.000e+00, Loss_ut_ics: 1.963e-04, Loss_norm: 1.319e-04, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 1.615e-02, lr: 1.000e-03, Time: 3.62e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 260, Loss: 6.204e+00, Loss_res: 5.764e+00,  Loss_bcs: 0.000e+00, Loss_ut_ics: 5.442e-04, Loss_norm: 4.134e-04, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 1.662e-02, lr: 1.000e-03, Time: 3.75e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 270, Loss: 5.449e+00, Loss_res: 5.250e+00,  Loss_bcs: 0.000e+00, Loss_ut_ics: 2.455e-04, Loss_norm: 2.552e-04, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 1.440e-02, lr: 1.000e-03, Time: 3.89e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 280, Loss: 5.407e+00, Loss_res: 5.240e+00,  Loss_bcs: 0.000e+00, Loss_ut_ics: 2.066e-04, Loss_norm: 2.056e-04, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 1.637e-02, lr: 1.000e-03, Time: 4.03e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 290, Loss: 5.573e+00, Loss_res: 5.383e+00,  Loss_bcs: 0.000e+00, Loss_ut_ics: 2.352e-04, Loss_norm: 2.493e-04, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 1.752e-02, lr: 1.000e-03, Time: 4.16e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 300, Loss: 5.181e+00, Loss_res: 4.981e+00,  Loss_bcs: 0.000e+00, Loss_ut_ics: 2.462e-04, Loss_norm: 2.681e-04, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 1.400e-02, lr: 1.000e-03, Time: 4.29e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 310, Loss: 5.583e+00, Loss_res: 5.435e+00,  Loss_bcs: 0.000e+00, Loss_ut_ics: 1.827e-04, Loss_norm: 1.753e-04, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 1.352e-02, lr: 1.000e-03, Time: 4.44e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 320, Loss: 5.873e+00, Loss_res: 5.698e+00,  Loss_bcs: 0.000e+00, Loss_ut_ics: 2.156e-04, Loss_norm: 2.272e-04, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 1.515e-02, lr: 1.000e-03, Time: 4.59e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 330, Loss: 5.332e+00, Loss_res: 5.112e+00,  Loss_bcs: 0.000e+00, Loss_ut_ics: 2.707e-04, Loss_norm: 2.876e-04, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 1.459e-02, lr: 1.000e-03, Time: 4.74e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 340, Loss: 5.174e+00, Loss_res: 5.037e+00,  Loss_bcs: 0.000e+00, Loss_ut_ics: 1.690e-04, Loss_norm: 1.376e-04, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 1.297e-02, lr: 1.000e-03, Time: 4.90e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 350, Loss: 5.288e+00, Loss_res: 5.015e+00,  Loss_bcs: 0.000e+00, Loss_ut_ics: 3.379e-04, Loss_norm: 3.317e-04, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 1.730e-02, lr: 1.000e-03, Time: 5.05e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 360, Loss: 5.377e+00, Loss_res: 5.226e+00,  Loss_bcs: 0.000e+00, Loss_ut_ics: 1.867e-04, Loss_norm: 1.847e-04, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 1.384e-02, lr: 1.000e-03, Time: 5.20e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 370, Loss: 4.931e+00, Loss_res: 4.782e+00,  Loss_bcs: 0.000e+00, Loss_ut_ics: 1.822e-04, Loss_norm: 2.390e-04, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 1.321e-02, lr: 1.000e-03, Time: 5.34e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 380, Loss: 5.797e+00, Loss_res: 5.579e+00,  Loss_bcs: 0.000e+00, Loss_ut_ics: 2.707e-04, Loss_norm: 1.268e-04, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 1.604e-02, lr: 1.000e-03, Time: 5.49e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 390, Loss: 5.370e+00, Loss_res: 5.120e+00,  Loss_bcs: 0.000e+00, Loss_ut_ics: 3.079e-04, Loss_norm: 3.559e-04, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 1.337e-02, lr: 1.000e-03, Time: 5.63e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 400, Loss: 5.314e+00, Loss_res: 4.998e+00,  Loss_bcs: 0.000e+00, Loss_ut_ics: 3.897e-04, Loss_norm: 3.874e-04, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 1.346e-02, lr: 1.000e-03, Time: 5.78e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 410, Loss: 5.165e+00, Loss_res: 5.014e+00,  Loss_bcs: 0.000e+00, Loss_ut_ics: 1.872e-04, Loss_norm: 1.901e-04, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 1.350e-02, lr: 1.000e-03, Time: 5.93e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 420, Loss: 4.627e+00, Loss_res: 4.407e+00,  Loss_bcs: 0.000e+00, Loss_ut_ics: 2.723e-04, Loss_norm: 2.384e-04, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 1.674e-02, lr: 1.000e-03, Time: 6.07e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 430, Loss: 4.762e+00, Loss_res: 4.613e+00,  Loss_bcs: 0.000e+00, Loss_ut_ics: 1.836e-04, Loss_norm: 1.699e-04, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 1.529e-02, lr: 1.000e-03, Time: 6.22e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 440, Loss: 5.244e+00, Loss_res: 5.116e+00,  Loss_bcs: 0.000e+00, Loss_ut_ics: 1.579e-04, Loss_norm: 1.347e-04, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 1.350e-02, lr: 1.000e-03, Time: 6.37e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# INFO:src.utils.logger:It: 450, Loss: 5.189e+00, Loss_res: 4.979e+00,  Loss_bcs: 0.000e+00, Loss_ut_ics: 2.596e-04, Loss_norm: 2.277e-04, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 1.228e-02, lr: 1.000e-03, Time: 6.53e+02
# INFO:src.utils.logger:Model state saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model.pth
# INFO:src.utils.logger:Model weights saved to C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025\results\2025-12-23_14-55-24-663399\model_weights.pth
# Etapa 2 (Physics-informed) terminada.
# [Metrics @ t=0.2] L2_complex=0.0123 | L2_phase=0.0117 | L2_density=0.0233

# %%
import numpy as np

Nt, Nx = 80, 220
t_grid = torch.linspace(0.0, float(problem["T"]), Nt, device=device_, dtype=dtype_).reshape(-1,1)
x_grid = torch.linspace(problem["x_min"], problem["x_max"], Nx, device=device_, dtype=dtype_).reshape(-1,1)

# mallado tipo (Nt*Nx, 1)
TT = t_grid.repeat(1, Nx).reshape(-1,1)
XX = x_grid.repeat(Nt, 1)

with torch.no_grad():
    re_ex, im_ex, _ = problem["exact"](problem["n_level"], TT, XX)
    y_pr = model(torch.cat([TT, XX], dim=1))
    re_pr, im_pr = y_pr[:,0:1], y_pr[:,1:2]

re_ex = re_ex.reshape(Nt, Nx).detach().cpu().numpy()
im_ex = im_ex.reshape(Nt, Nx).detach().cpu().numpy()
re_pr = re_pr.reshape(Nt, Nx).detach().cpu().numpy()
im_pr = im_pr.reshape(Nt, Nx).detach().cpu().numpy()

re_er = re_pr - re_ex
im_er = im_pr - im_ex

extent = [float(problem["x_min"]), float(problem["x_max"]), float(problem["T"]), 0.0]

plt.figure(figsize=(12,8))

plt.subplot(3,2,1); plt.imshow(re_ex, aspect="auto", extent=extent); plt.title("Re exact"); plt.ylabel("t"); plt.colorbar()
plt.subplot(3,2,2); plt.imshow(re_pr, aspect="auto", extent=extent); plt.title("Re pred");  plt.colorbar()

plt.subplot(3,2,3); plt.imshow(im_ex, aspect="auto", extent=extent); plt.title("Im exact"); plt.ylabel("t"); plt.colorbar()
plt.subplot(3,2,4); plt.imshow(im_pr, aspect="auto", extent=extent); plt.title("Im pred");  plt.colorbar()

plt.subplot(3,2,5); plt.imshow(re_er, aspect="auto", extent=extent); plt.title("Re error"); plt.xlabel("x"); plt.ylabel("t"); plt.colorbar()
plt.subplot(3,2,6); plt.imshow(im_er, aspect="auto", extent=extent); plt.title("Im error"); plt.xlabel("x"); plt.colorbar()

plt.tight_layout()
plt.show()

# %%
loss_hist = np.array(getattr(model, "loss_history", []), dtype=float)
l2_hist   = np.array(getattr(model, "l2_rel_history", []), dtype=float)

plt.figure(figsize=(7,3))
if len(loss_hist) > 0:
    plt.plot(loss_hist)
plt.yscale("log")
plt.title("Loss vs epochs")
plt.xlabel("epoch")
plt.ylabel("loss")
plt.tight_layout()
plt.show()

plt.figure(figsize=(7,3))
if len(l2_hist) > 0:
    plt.plot(l2_hist)
plt.title("L2_rel (como lo reporta el trainer) vs epochs")
plt.xlabel("epoch")
plt.ylabel("L2_rel")
plt.tight_layout()
plt.show()

# %%
def plot_heatmaps(problem, model, nx=120, nt=80):
    device_ = next(model.parameters()).device
    dtype_  = next(model.parameters()).dtype

    x = torch.linspace(problem["x_min"], problem["x_max"], nx, device=device_, dtype=dtype_).reshape(-1,1)
    t = torch.linspace(0.0, float(problem["T"]), nt, device=device_, dtype=dtype_).reshape(-1,1)

    TT, XX = torch.meshgrid(t.squeeze(1), x.squeeze(1), indexing="ij")
    tx = torch.stack([TT.reshape(-1), XX.reshape(-1)], dim=1)

    with torch.no_grad():
        out = model(tx)
        re_p = out[:,0].reshape(nt, nx).detach().cpu().numpy()
        im_p = out[:,1].reshape(nt, nx).detach().cpu().numpy()

        re_e, im_e, _ = problem["exact"](problem["n_level"], tx[:,0:1], tx[:,1:2])
        re_e = re_e.reshape(nt, nx).detach().cpu().numpy()
        im_e = im_e.reshape(nt, nx).detach().cpu().numpy()

    def show(A, title):
        plt.figure(figsize=(6,3.2))
        plt.imshow(A, aspect="auto", origin="upper",
                   extent=[float(problem["x_min"]), float(problem["x_max"]), float(problem["T"]), 0.0])
        plt.colorbar()
        plt.title(title)
        plt.xlabel("x")
        plt.ylabel("t")
        plt.tight_layout()
        plt.show()

    show(re_e, "Re exact")
    show(re_p, "Re pred")
    show(re_p - re_e, "Re error")

    show(im_e, "Im exact")
    show(im_p, "Im pred")
    show(im_p - im_e, "Im error")

plot_heatmaps(problem, model)
