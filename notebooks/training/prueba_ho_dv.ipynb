# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

# %%
import torch
import matplotlib.pyplot as plt

device = "cuda" if torch.cuda.is_available() else "cpu"
dtype  = "float32"   # DVPDESolver/DVQuantumLayer trabajan más estable así en tu repo

torch.manual_seed(0)
if device == "cuda":
    torch.cuda.manual_seed_all(0)

print("device:", device, "| dtype:", dtype)
# Out:
# device: cpu | dtype: float32

# %%
import importlib

import src.trainer.schrodinger_train as sch_train
import src.nn.DVPDESolver as dv_solver_mod

importlib.reload(sch_train)
importlib.reload(dv_solver_mod)

from src.trainer.schrodinger_train import train
from src.nn.DVPDESolver import DVPDESolver

from src.problems.schrodinger import build_eq_params, sanity_check
from src.problems.schrodinger.problem import build_problem
from src.utils.logger import Logging

# %%
eq_params = build_eq_params(
    "ho",
    L=6.0,          # dominio truncado [-L, L]
    T=0.2,
    mass=1.0,
    hbar=1.0,
    omega=1.0,
    n_level=0,      # prueba n=1 primero
    num_grid=800,
)

print("eq_params:", eq_params)
print("sanity:", sanity_check(eq_params, device=device))
# Out:
# eq_params: {'example': 'ho', 'L': 6.0, 'T': 0.2, 'mass': 1.0, 'hbar': 1.0, 'n_level': 0, 'x_min': -6.0, 'x_max': 6.0, 'omega': 1.0, 'V0': 50.0, 'barrier_width': 1.2, 'x_center': 3.0, 'num_grid': 800}
# sanity: {'V_min': 0.00045453397641474763, 'V_max': 18.0, 'psi0_norm': 0.28795254238618323, 'psiT_norm': 0.28795254238618323}

# %%
pb = build_problem(
    eq_params,
    device=torch.device(device),
    dtype=torch.float32 if "32" in dtype else torch.float64
)

x = torch.linspace(pb["x_min"], pb["x_max"], 1200, device=device, dtype=pb["dtype"]).reshape(-1, 1)
t0 = torch.zeros_like(x)
tT = torch.full_like(x, pb["T"])

with torch.no_grad():
    V = pb["potential_fn"](t0, x)
    r0,i0,_ = pb["exact"](pb["n_level"], t0, x)
    rT,iT,_ = pb["exact"](pb["n_level"], tT, x)

x_cpu = x.detach().cpu().numpy().flatten()
V_cpu = V.detach().cpu().numpy().flatten()
p0_cpu = (r0**2 + i0**2).detach().cpu().numpy().flatten()
pT_cpu = (rT**2 + iT**2).detach().cpu().numpy().flatten()

plt.figure()
plt.plot(x_cpu, V_cpu)
plt.xlabel("x"); plt.ylabel("V(x)")
plt.title("HO: Potencial")
plt.show()

plt.figure()
plt.plot(x_cpu, p0_cpu, label="|psi(x,0)|^2 exact")
plt.plot(x_cpu, pT_cpu, label="|psi(x,T)|^2 exact")
plt.legend()
plt.xlabel("x"); plt.ylabel("|psi|^2")
plt.title("HO: Exacta (|psi|^2 es estacionaria)")
plt.show()

# %%
args = {
    "eq_params": eq_params,
    "device": device,
    "dtype": dtype,
    "problem": "schrodinger",
    "dv_batching": True,
    "pde_chunk_size": 128,
    "dv_batching_mode": "broadcast",
    


    # training
    "epochs": 500,        # smoke test (sube luego a 1500-3000)
    "lr": 1e-3,
    "batch_size": 64,
    "print_every": 10,

    # pesos (HO suele ir bien con esto)
    "w_pde": 1.0,
    "w_bc":  1.0,         # cola ~0 en bordes del dominio truncado
    "w_ic":  200.0,
    "w_norm": 5.0,
    "w_pde_i": 10.0,
    "w_ic_i": 5.0,
    

    "warmup_epochs": 20,
    "ic_grid": True,
    "N_norm": 400,
    "N_val": 400,

    # DV (circuito)
    "num_qubits": 4,
    "num_quantum_layers": 2,
    "shots": None,        # requerido por el layer aunque default.qubit no lo use
    "noise": False,
    "encoding": "angle",
    "q_ansatz": "sim_circ_19",

    # red híbrida (ojo: en DVPDESolver solo usa [-2] y [-1])
    "classic_network": [2, 64, 2],   # input=2 (t,x), hidden=64, output=2 (Re,Im)
}

logger = Logging("./results/models/checkpoints/smoke_schrodinger", "ho_DV")
model = DVPDESolver(args, logger, device=torch.device(device))
model.args = args

# opcional: no dibujar el circuito cada corrida (ahorra tiempo)
model.draw_quantum_circuit_flag = False

print("DV model built.")
# Out:
# DV model built.

# %%
param_dtype = next(model.parameters()).dtype
t_test = torch.rand(8, 1, device=device, dtype=param_dtype) * eq_params["T"]
x_test = (torch.rand(8, 1, device=device, dtype=param_dtype) * (eq_params["x_max"] - eq_params["x_min"]) + eq_params["x_min"])
y = model(torch.cat([t_test, x_test], dim=1))

print("forward ok ->", y.shape, y.dtype, y.device)
# Out:
# forward ok -> torch.Size([8, 2]) torch.float32 cpu

# %%
train(model, N_f=500, N_b=128, N_0=260)
# Out:
# INFO:src.utils.logger:It: 1, Loss: 4.098e-02, Loss_res: 3.279e-02,  Loss_bcs: 2.016e-04, Loss_ut_ics: 1.953e-04, Loss_norm: 1.519e-05, Loss_gauge: 0.000e+00, w_pde: 5.00e-02, L^2_error: 1.634e-01, lr: 1.000e-03, Time: 8.46e-01
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model_weights.pth
# INFO:src.utils.logger:It: 10, Loss: 1.932e-01, Loss_res: 1.129e-01,  Loss_bcs: 5.151e-04, Loss_ut_ics: 6.428e-04, Loss_norm: 1.537e-03, Loss_gauge: 0.000e+00, w_pde: 5.00e-01, L^2_error: 1.252e-01, lr: 1.000e-03, Time: 8.40e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model_weights.pth
# INFO:src.utils.logger:It: 20, Loss: 9.748e-02, Loss_res: 4.867e-02,  Loss_bcs: 3.499e-04, Loss_ut_ics: 2.026e-04, Loss_norm: 1.588e-03, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 1.065e-01, lr: 1.000e-03, Time: 1.70e+01
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model_weights.pth
# INFO:src.utils.logger:It: 30, Loss: 5.873e-02, Loss_res: 3.064e-02,  Loss_bcs: 1.629e-04, Loss_ut_ics: 1.130e-04, Loss_norm: 1.066e-03, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 1.073e-01, lr: 1.000e-03, Time: 2.52e+01
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model_weights.pth
# INFO:src.utils.logger:It: 40, Loss: 4.262e-02, Loss_res: 2.714e-02,  Loss_bcs: 6.685e-05, Loss_ut_ics: 7.249e-05, Loss_norm: 1.835e-04, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 1.024e-01, lr: 1.000e-03, Time: 3.37e+01
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model_weights.pth
# INFO:src.utils.logger:It: 50, Loss: 3.429e-02, Loss_res: 2.459e-02,  Loss_bcs: 1.062e-04, Loss_ut_ics: 4.668e-05, Loss_norm: 5.048e-05, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 1.036e-01, lr: 1.000e-03, Time: 4.20e+01
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model_weights.pth
# INFO:src.utils.logger:It: 60, Loss: 3.063e-02, Loss_res: 2.350e-02,  Loss_bcs: 9.475e-05, Loss_ut_ics: 3.492e-05, Loss_norm: 9.264e-06, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 1.011e-01, lr: 1.000e-03, Time: 5.04e+01
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model_weights.pth
# INFO:src.utils.logger:It: 70, Loss: 2.962e-02, Loss_res: 2.332e-02,  Loss_bcs: 7.029e-05, Loss_ut_ics: 3.096e-05, Loss_norm: 6.582e-06, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 1.008e-01, lr: 1.000e-03, Time: 5.91e+01
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model_weights.pth
# INFO:src.utils.logger:It: 80, Loss: 2.883e-02, Loss_res: 2.338e-02,  Loss_bcs: 7.681e-05, Loss_ut_ics: 2.664e-05, Loss_norm: 7.772e-06, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 1.010e-01, lr: 1.000e-03, Time: 6.82e+01
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model_weights.pth
# INFO:src.utils.logger:It: 90, Loss: 2.730e-02, Loss_res: 2.255e-02,  Loss_bcs: 7.040e-05, Loss_ut_ics: 2.329e-05, Loss_norm: 4.602e-06, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 1.007e-01, lr: 1.000e-03, Time: 7.67e+01
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model_weights.pth
# INFO:src.utils.logger:It: 100, Loss: 2.990e-02, Loss_res: 2.570e-02,  Loss_bcs: 5.604e-05, Loss_ut_ics: 2.058e-05, Loss_norm: 6.147e-06, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 1.003e-01, lr: 1.000e-03, Time: 8.53e+01
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model_weights.pth
# INFO:src.utils.logger:It: 110, Loss: 2.378e-02, Loss_res: 1.998e-02,  Loss_bcs: 5.732e-05, Loss_ut_ics: 1.855e-05, Loss_norm: 5.670e-06, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 9.996e-02, lr: 1.000e-03, Time: 9.38e+01
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model_weights.pth
# INFO:src.utils.logger:It: 120, Loss: 2.292e-02, Loss_res: 1.955e-02,  Loss_bcs: 4.401e-05, Loss_ut_ics: 1.650e-05, Loss_norm: 3.872e-06, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 9.958e-02, lr: 1.000e-03, Time: 1.02e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model_weights.pth
# INFO:src.utils.logger:It: 130, Loss: 2.470e-02, Loss_res: 2.168e-02,  Loss_bcs: 3.580e-05, Loss_ut_ics: 1.483e-05, Loss_norm: 3.551e-06, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 9.917e-02, lr: 1.000e-03, Time: 1.11e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model_weights.pth
# INFO:src.utils.logger:It: 140, Loss: 2.455e-02, Loss_res: 2.188e-02,  Loss_bcs: 3.814e-05, Loss_ut_ics: 1.304e-05, Loss_norm: 3.672e-06, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 9.888e-02, lr: 1.000e-03, Time: 1.20e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model_weights.pth
# INFO:src.utils.logger:It: 150, Loss: 2.422e-02, Loss_res: 2.181e-02,  Loss_bcs: 4.256e-05, Loss_ut_ics: 1.175e-05, Loss_norm: 4.140e-06, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 9.848e-02, lr: 1.000e-03, Time: 1.29e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model_weights.pth
# INFO:src.utils.logger:It: 160, Loss: 1.976e-02, Loss_res: 1.758e-02,  Loss_bcs: 3.453e-05, Loss_ut_ics: 1.064e-05, Loss_norm: 3.556e-06, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 9.833e-02, lr: 1.000e-03, Time: 1.37e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model_weights.pth
# INFO:src.utils.logger:It: 170, Loss: 2.514e-02, Loss_res: 2.315e-02,  Loss_bcs: 2.711e-05, Loss_ut_ics: 9.713e-06, Loss_norm: 3.810e-06, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 9.816e-02, lr: 1.000e-03, Time: 1.46e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model_weights.pth
# INFO:src.utils.logger:It: 180, Loss: 2.067e-02, Loss_res: 1.886e-02,  Loss_bcs: 2.789e-05, Loss_ut_ics: 8.839e-06, Loss_norm: 3.662e-06, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 9.786e-02, lr: 1.000e-03, Time: 1.55e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model_weights.pth
# INFO:src.utils.logger:It: 190, Loss: 2.065e-02, Loss_res: 1.900e-02,  Loss_bcs: 2.573e-05, Loss_ut_ics: 8.032e-06, Loss_norm: 4.115e-06, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 9.759e-02, lr: 1.000e-03, Time: 1.64e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model_weights.pth
# INFO:src.utils.logger:It: 200, Loss: 2.312e-02, Loss_res: 2.159e-02,  Loss_bcs: 2.123e-05, Loss_ut_ics: 7.454e-06, Loss_norm: 4.051e-06, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 9.736e-02, lr: 1.000e-03, Time: 1.72e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model_weights.pth
# INFO:src.utils.logger:It: 210, Loss: 2.009e-02, Loss_res: 1.868e-02,  Loss_bcs: 1.616e-05, Loss_ut_ics: 6.811e-06, Loss_norm: 4.377e-06, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 9.708e-02, lr: 1.000e-03, Time: 1.81e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model_weights.pth
# INFO:src.utils.logger:It: 220, Loss: 2.355e-02, Loss_res: 2.224e-02,  Loss_bcs: 1.673e-05, Loss_ut_ics: 6.365e-06, Loss_norm: 3.936e-06, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 9.684e-02, lr: 1.000e-03, Time: 1.89e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model_weights.pth
# INFO:src.utils.logger:It: 230, Loss: 2.022e-02, Loss_res: 1.898e-02,  Loss_bcs: 1.787e-05, Loss_ut_ics: 6.023e-06, Loss_norm: 5.247e-06, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 9.651e-02, lr: 1.000e-03, Time: 1.98e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model_weights.pth
# INFO:src.utils.logger:It: 240, Loss: 2.250e-02, Loss_res: 2.135e-02,  Loss_bcs: 1.756e-05, Loss_ut_ics: 5.549e-06, Loss_norm: 4.453e-06, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 9.633e-02, lr: 1.000e-03, Time: 2.07e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model_weights.pth
# INFO:src.utils.logger:It: 250, Loss: 2.144e-02, Loss_res: 2.037e-02,  Loss_bcs: 1.674e-05, Loss_ut_ics: 5.158e-06, Loss_norm: 4.891e-06, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 9.614e-02, lr: 1.000e-03, Time: 2.15e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model_weights.pth
# INFO:src.utils.logger:It: 260, Loss: 2.532e-02, Loss_res: 2.427e-02,  Loss_bcs: 1.171e-05, Loss_ut_ics: 5.091e-06, Loss_norm: 5.285e-06, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 9.574e-02, lr: 1.000e-03, Time: 2.24e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model_weights.pth
# INFO:src.utils.logger:It: 270, Loss: 2.158e-02, Loss_res: 2.064e-02,  Loss_bcs: 1.262e-05, Loss_ut_ics: 4.479e-06, Loss_norm: 4.649e-06, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 9.555e-02, lr: 1.000e-03, Time: 2.32e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model_weights.pth
# INFO:src.utils.logger:It: 280, Loss: 2.034e-02, Loss_res: 1.938e-02,  Loss_bcs: 1.254e-05, Loss_ut_ics: 4.605e-06, Loss_norm: 5.947e-06, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 9.519e-02, lr: 1.000e-03, Time: 2.41e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model_weights.pth
# INFO:src.utils.logger:It: 290, Loss: 2.021e-02, Loss_res: 1.931e-02,  Loss_bcs: 9.119e-06, Loss_ut_ics: 4.316e-06, Loss_norm: 5.106e-06, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 9.494e-02, lr: 1.000e-03, Time: 2.49e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model_weights.pth
# INFO:src.utils.logger:It: 300, Loss: 2.147e-02, Loss_res: 2.061e-02,  Loss_bcs: 1.117e-05, Loss_ut_ics: 4.098e-06, Loss_norm: 5.208e-06, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 9.474e-02, lr: 1.000e-03, Time: 2.58e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model_weights.pth
# INFO:src.utils.logger:It: 310, Loss: 2.120e-02, Loss_res: 2.035e-02,  Loss_bcs: 9.618e-06, Loss_ut_ics: 4.080e-06, Loss_norm: 6.060e-06, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 9.429e-02, lr: 1.000e-03, Time: 2.67e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model_weights.pth
# INFO:src.utils.logger:It: 320, Loss: 1.865e-02, Loss_res: 1.783e-02,  Loss_bcs: 8.581e-06, Loss_ut_ics: 3.917e-06, Loss_norm: 4.918e-06, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 9.410e-02, lr: 1.000e-03, Time: 2.76e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model_weights.pth
# INFO:src.utils.logger:It: 330, Loss: 2.132e-02, Loss_res: 2.054e-02,  Loss_bcs: 7.290e-06, Loss_ut_ics: 3.685e-06, Loss_norm: 5.535e-06, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 9.362e-02, lr: 1.000e-03, Time: 2.84e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model_weights.pth
# INFO:src.utils.logger:It: 340, Loss: 1.965e-02, Loss_res: 1.889e-02,  Loss_bcs: 7.503e-06, Loss_ut_ics: 3.615e-06, Loss_norm: 5.202e-06, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 9.334e-02, lr: 1.000e-03, Time: 2.94e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model_weights.pth
# INFO:src.utils.logger:It: 350, Loss: 1.544e-02, Loss_res: 1.467e-02,  Loss_bcs: 6.205e-06, Loss_ut_ics: 3.677e-06, Loss_norm: 5.707e-06, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 9.285e-02, lr: 1.000e-03, Time: 3.02e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model_weights.pth
# INFO:src.utils.logger:It: 360, Loss: 1.922e-02, Loss_res: 1.849e-02,  Loss_bcs: 7.026e-06, Loss_ut_ics: 3.467e-06, Loss_norm: 5.423e-06, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 9.256e-02, lr: 1.000e-03, Time: 3.10e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model_weights.pth
# INFO:src.utils.logger:It: 370, Loss: 1.730e-02, Loss_res: 1.654e-02,  Loss_bcs: 5.361e-06, Loss_ut_ics: 3.630e-06, Loss_norm: 6.300e-06, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 9.232e-02, lr: 1.000e-03, Time: 3.19e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model_weights.pth
# INFO:src.utils.logger:It: 380, Loss: 2.031e-02, Loss_res: 1.960e-02,  Loss_bcs: 6.559e-06, Loss_ut_ics: 3.381e-06, Loss_norm: 6.032e-06, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 9.176e-02, lr: 1.000e-03, Time: 3.28e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model_weights.pth
# INFO:src.utils.logger:It: 390, Loss: 1.733e-02, Loss_res: 1.665e-02,  Loss_bcs: 5.414e-06, Loss_ut_ics: 3.251e-06, Loss_norm: 5.416e-06, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 9.132e-02, lr: 1.000e-03, Time: 3.37e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model_weights.pth
# INFO:src.utils.logger:It: 400, Loss: 1.868e-02, Loss_res: 1.795e-02,  Loss_bcs: 5.844e-06, Loss_ut_ics: 3.449e-06, Loss_norm: 6.012e-06, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 9.093e-02, lr: 1.000e-03, Time: 3.46e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model_weights.pth
# INFO:src.utils.logger:It: 410, Loss: 2.098e-02, Loss_res: 2.024e-02,  Loss_bcs: 5.544e-06, Loss_ut_ics: 3.511e-06, Loss_norm: 5.891e-06, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 9.053e-02, lr: 1.000e-03, Time: 3.55e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model_weights.pth
# INFO:src.utils.logger:It: 420, Loss: 1.640e-02, Loss_res: 1.572e-02,  Loss_bcs: 4.571e-06, Loss_ut_ics: 3.268e-06, Loss_norm: 5.652e-06, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 8.991e-02, lr: 1.000e-03, Time: 3.64e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model_weights.pth
# INFO:src.utils.logger:It: 430, Loss: 1.632e-02, Loss_res: 1.564e-02,  Loss_bcs: 5.052e-06, Loss_ut_ics: 3.186e-06, Loss_norm: 5.953e-06, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 8.933e-02, lr: 1.000e-03, Time: 3.72e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model_weights.pth
# INFO:src.utils.logger:It: 440, Loss: 1.973e-02, Loss_res: 1.903e-02,  Loss_bcs: 4.379e-06, Loss_ut_ics: 3.350e-06, Loss_norm: 4.533e-06, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 8.895e-02, lr: 1.000e-03, Time: 3.81e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model_weights.pth
# INFO:src.utils.logger:It: 450, Loss: 1.862e-02, Loss_res: 1.792e-02,  Loss_bcs: 3.390e-06, Loss_ut_ics: 3.327e-06, Loss_norm: 5.732e-06, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 8.836e-02, lr: 1.000e-03, Time: 3.89e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model_weights.pth
# INFO:src.utils.logger:It: 460, Loss: 1.512e-02, Loss_res: 1.441e-02,  Loss_bcs: 4.983e-06, Loss_ut_ics: 3.394e-06, Loss_norm: 5.569e-06, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 8.772e-02, lr: 1.000e-03, Time: 3.97e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model_weights.pth
# INFO:src.utils.logger:It: 470, Loss: 1.827e-02, Loss_res: 1.757e-02,  Loss_bcs: 5.212e-06, Loss_ut_ics: 3.362e-06, Loss_norm: 4.571e-06, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 8.677e-02, lr: 1.000e-03, Time: 4.06e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model_weights.pth
# INFO:src.utils.logger:It: 480, Loss: 1.908e-02, Loss_res: 1.839e-02,  Loss_bcs: 4.021e-06, Loss_ut_ics: 3.267e-06, Loss_norm: 7.003e-06, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 8.606e-02, lr: 1.000e-03, Time: 4.14e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model_weights.pth
# INFO:src.utils.logger:It: 490, Loss: 1.841e-02, Loss_res: 1.770e-02,  Loss_bcs: 3.702e-06, Loss_ut_ics: 3.409e-06, Loss_norm: 5.165e-06, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 8.537e-02, lr: 1.000e-03, Time: 4.22e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model_weights.pth
# INFO:src.utils.logger:It: 500, Loss: 1.754e-02, Loss_res: 1.684e-02,  Loss_bcs: 4.625e-06, Loss_ut_ics: 3.328e-06, Loss_norm: 5.232e-06, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 8.427e-02, lr: 1.000e-03, Time: 4.31e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2025-12-21_16-17-31-609597_ho_DV\model_weights.pth

# %%
import torch
import matplotlib.pyplot as plt
from src.problems.schrodinger.problem import build_problem

def normalize_dtype(dt):
    if isinstance(dt, torch.dtype):
        return dt
    if isinstance(dt, str):
        dt = dt.lower()
        if "32" in dt:
            return torch.float32
        if "64" in dt:
            return torch.float64
    raise ValueError(f"dtype no reconocido: {dt} ({type(dt)})")

pb = build_problem(
    eq_params,
    device=torch.device(device),
    dtype=normalize_dtype(dtype)
)

x = torch.linspace(pb["x_min"], pb["x_max"], 1200, device=pb["device"], dtype=pb["dtype"]).reshape(-1, 1)
t = torch.full_like(x, float(pb["T"]))

with torch.no_grad():
    pred = model(torch.cat([t, x], dim=1))
    pr, pi = pred[:, 0:1], pred[:, 1:2]
    er, ei, _ = pb["exact"](pb["n_level"], t, x)

    l2_abs = torch.sqrt(torch.mean((pr-er)**2 + (pi-ei)**2))
    ref = torch.sqrt(torch.mean(er**2 + ei**2)) + 1e-12
    l2_rel = (l2_abs / ref).item()

print("L2_rel(T):", l2_rel)

prob_pred  = (pr**2 + pi**2).detach().cpu().numpy().flatten()
prob_exact = (er**2 + ei**2).detach().cpu().numpy().flatten()
x_cpu      = x.detach().cpu().numpy().flatten()

plt.figure()
plt.plot(x_cpu, prob_exact, label="exact")
plt.plot(x_cpu, prob_pred,  label="pred")
plt.legend()
plt.xlabel("x"); plt.ylabel(r"$|\psi(x,T)|^2$")
plt.title(f"HO (DV) n={eq_params['n_level']}  L2_rel(T)={l2_rel:.3e}")
plt.show()
# Out:
# L2_rel(T): 0.0842677503824234

# %%
x = torch.linspace(pb["x_min"], pb["x_max"], 1400, device=device, dtype=pb["dtype"]).reshape(-1,1)
t0 = torch.zeros_like(x)
tT = torch.full_like(x, pb["T"])

with torch.no_grad():
    p0 = model(torch.cat([t0, x], dim=1))
    pT = model(torch.cat([tT, x], dim=1))

    prob0 = p0[:,0]**2 + p0[:,1]**2
    probT = pT[:,0]**2 + pT[:,1]**2

    norm0 = torch.trapz(prob0, x.squeeze(-1)).item()
    normT = torch.trapz(probT, x.squeeze(-1)).item()

print("Norm pred t=0:", norm0)
print("Norm pred t=T:", normT)
# Out:
# Norm pred t=0: 0.998199462890625
# Norm pred t=T: 1.0028562545776367

# %%
print("broadcast_ok:", getattr(model.quantum_layer, "_broadcast_ok", None))
print("dv_batching_mode:", getattr(model.quantum_layer, "dv_batching_mode", None))
# Out:
# broadcast_ok: True
# dv_batching_mode: broadcast

# %%
import torch

def count_params(model):
    total = 0
    trainable = 0
    by_block = {}  # desglose por prefijo: preprocessor / quantum_layer / postprocessor / hidden / etc.

    for name, p in model.named_parameters():
        n = p.numel()
        total += n
        if p.requires_grad:
            trainable += n

        block = name.split(".")[0]  # primer prefijo (preprocessor, quantum_layer, postprocessor, etc.)
        by_block.setdefault(block, {"total": 0, "trainable": 0})
        by_block[block]["total"] += n
        if p.requires_grad:
            by_block[block]["trainable"] += n

    return total, trainable, by_block


total, trainable, by_block = count_params(model)

print(f"Total parámetros (incluye no-entrenables): {total:,}")
print(f"Parámetros ENTRENABLES (clásicos + cuánticos): {trainable:,}\n")

print("Desglose por bloque (trainables / total):")
for k, v in sorted(by_block.items(), key=lambda kv: -kv[1]["trainable"]):
    print(f"  - {k:15s}: {v['trainable']:,} / {v['total']:,}")

# si quieres además listar SOLO los tensores entrenables:
print("\nListado de parámetros entrenables:")
for name, p in model.named_parameters():
    if p.requires_grad:
        print(f"  {name:40s} {tuple(p.shape)}  numel={p.numel():,}  dtype={p.dtype}")
# Out:
# Total parámetros (incluye no-entrenables): 918
# Parámetros ENTRENABLES (clásicos + cuánticos): 918
#
# Desglose por bloque (trainables / total):
#   - preprocessor   : 452 / 452
#   - postprocessor  : 450 / 450
#   - quantum_layer  : 16 / 16
#
# Listado de parámetros entrenables:
#   preprocessor.0.weight                    (64, 2)  numel=128  dtype=torch.float32
#   preprocessor.0.bias                      (64,)  numel=64  dtype=torch.float32
#   preprocessor.2.weight                    (4, 64)  numel=256  dtype=torch.float32
#   preprocessor.2.bias                      (4,)  numel=4  dtype=torch.float32
#   quantum_layer.params                     (2, 8)  numel=16  dtype=torch.float32
#   postprocessor.0.weight                   (64, 4)  numel=256  dtype=torch.float32
#   postprocessor.0.bias                     (64,)  numel=64  dtype=torch.float32
#   postprocessor.2.weight                   (2, 64)  numel=128  dtype=torch.float32
#   postprocessor.2.bias                     (2,)  numel=2  dtype=torch.float32

# %%
import numpy as np
import matplotlib.pyplot as plt

def get_history(model):
    # intentos comunes (por si el nombre cambia)
    l2_keys = ["l2_rel_history", "l2_history", "l2_error_history"]
    loss_keys = ["loss_history", "losses", "train_loss_history"]

    l2 = None
    for k in l2_keys:
        if hasattr(model, k) and len(getattr(model, k)) > 0:
            l2 = np.array(getattr(model, k), dtype=float)
            break

    loss = None
    for k in loss_keys:
        if hasattr(model, k) and len(getattr(model, k)) > 0:
            loss = np.array(getattr(model, k), dtype=float)
            break

    return loss, l2


loss, l2 = get_history(model)

if loss is None:
    raise AttributeError("No encontré historial de pérdida en el modelo (esperaba model.loss_history).")

if l2 is None:
    raise AttributeError("No encontré historial de error L2 en el modelo (esperaba model.l2_rel_history).")

epochs_loss = np.arange(1, len(loss) + 1)
epochs_l2   = np.arange(1, len(l2) + 1)

plt.figure()
plt.plot(epochs_l2, l2)
plt.xlabel("Época")
plt.ylabel(r"$L^2_{\mathrm{rel}}(t=T)$")
plt.title("Error relativo vs épocas")
plt.grid(True)
plt.show()

plt.figure()
plt.plot(epochs_loss, loss)
plt.yscale("log")
plt.xlabel("Época")
plt.ylabel("Loss (log)")
plt.title("Loss vs épocas")
plt.grid(True)
plt.show()

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

# Necesario: build_problem para exacta y dominio
from src.problems.schrodinger.problem import build_problem

@torch.no_grad()
def eval_model_in_chunks(model, tx, chunk=512):
    """
    Evalúa model(tx) en trozos para no reventar memoria y para no hacer una sola llamada gigante (útil en DV).
    tx: (N,2)
    """
    model.eval()
    outs = []
    N = tx.shape[0]
    for i in range(0, N, chunk):
        outs.append(model(tx[i:i+chunk]))
    return torch.cat(outs, dim=0)

def plot_heatmaps_exact_pred_error(model, eq_params, Nt=120, Nx=220, chunk=512):
    device = next(model.parameters()).device
    dtype  = next(model.parameters()).dtype

    problem = build_problem(eq_params, device=device, dtype=dtype)
    T = float(problem["T"])
    x_min = float(problem["x_min"])
    x_max = float(problem["x_max"])
    n_level = int(problem["n_level"])

    # mallas
    t = torch.linspace(0.0, T, Nt, device=device, dtype=dtype)
    x = torch.linspace(x_min, x_max, Nx, device=device, dtype=dtype)
    TT, XX = torch.meshgrid(t, x, indexing="ij")  # (Nt,Nx)

    t_flat = TT.reshape(-1, 1)
    x_flat = XX.reshape(-1, 1)
    tx = torch.cat([t_flat, x_flat], dim=1)

    # exacta
    psi_r_ex, psi_i_ex, _ = problem["exact"](n_level, t_flat, x_flat)

    # predicción
    psi_pred = eval_model_in_chunks(model, tx, chunk=chunk)
    psi_r_pr = psi_pred[:, 0:1]
    psi_i_pr = psi_pred[:, 1:2]

    # reshape a (Nt,Nx)
    Re_ex = psi_r_ex.reshape(Nt, Nx).detach().cpu().numpy()
    Im_ex = psi_i_ex.reshape(Nt, Nx).detach().cpu().numpy()
    Re_pr = psi_r_pr.reshape(Nt, Nx).detach().cpu().numpy()
    Im_pr = psi_i_pr.reshape(Nt, Nx).detach().cpu().numpy()

    Re_er = np.abs(Re_pr - Re_ex)
    Im_er = np.abs(Im_pr - Im_ex)

    # escalas razonables (simétricas para Re/Im; positivas para error)
    re_max = max(np.max(np.abs(Re_ex)), np.max(np.abs(Re_pr))) + 1e-12
    im_max = max(np.max(np.abs(Im_ex)), np.max(np.abs(Im_pr))) + 1e-12
    re_e_max = np.max(Re_er) + 1e-12
    im_e_max = np.max(Im_er) + 1e-12

    extent = [0.0, T, x_min, x_max]  # x-axis=t, y-axis=x

    fig, axes = plt.subplots(2, 3, figsize=(14, 7), constrained_layout=True)

    # --- Re row ---
    im0 = axes[0,0].imshow(Re_ex, origin="lower", aspect="auto", extent=extent, vmin=-re_max, vmax=re_max)
    axes[0,0].set_title(r"Exact $\Re\{\psi(x,t)\}$")
    plt.colorbar(im0, ax=axes[0,0], fraction=0.046)

    im1 = axes[0,1].imshow(Re_pr, origin="lower", aspect="auto", extent=extent, vmin=-re_max, vmax=re_max)
    axes[0,1].set_title(r"Predicted $\Re\{\psi(x,t)\}$")
    plt.colorbar(im1, ax=axes[0,1], fraction=0.046)

    im2 = axes[0,2].imshow(Re_er, origin="lower", aspect="auto", extent=extent, vmin=0.0, vmax=re_e_max)
    axes[0,2].set_title(r"Error $|\Re\{\psi\}|$")
    plt.colorbar(im2, ax=axes[0,2], fraction=0.046)

    # --- Im row ---
    im3 = axes[1,0].imshow(Im_ex, origin="lower", aspect="auto", extent=extent, vmin=-im_max, vmax=im_max)
    axes[1,0].set_title(r"Exact $\Im\{\psi(x,t)\}$")
    plt.colorbar(im3, ax=axes[1,0], fraction=0.046)

    im4 = axes[1,1].imshow(Im_pr, origin="lower", aspect="auto", extent=extent, vmin=-im_max, vmax=im_max)
    axes[1,1].set_title(r"Predicted $\Im\{\psi(x,t)\}$")
    plt.colorbar(im4, ax=axes[1,1], fraction=0.046)

    im5 = axes[1,2].imshow(Im_er, origin="lower", aspect="auto", extent=extent, vmin=0.0, vmax=im_e_max)
    axes[1,2].set_title(r"Error $|\Im\{\psi\}|$")
    plt.colorbar(im5, ax=axes[1,2], fraction=0.046)

    for ax in axes.flat:
        ax.set_xlabel("t")
        ax.set_ylabel("x")

    ex = str(eq_params.get("example", "schrodinger")).upper()
    fig.suptitle(f"{ex} — Heatmaps exact/pred/error", fontsize=14)
    plt.show()

# ---- úsalo así ----
plot_heatmaps_exact_pred_error(model, eq_params, Nt=120, Nx=220, chunk=512)

# %%
import torch
from src.problems.schrodinger.problem import build_problem

device = next(model.parameters()).device
dtype  = next(model.parameters()).dtype
problem = build_problem(eq_params, device=device, dtype=dtype)

T = problem["T"]
x = torch.linspace(problem["x_min"], problem["x_max"], 300, device=device, dtype=dtype).reshape(-1,1)
t = torch.full_like(x, float(T))

with torch.no_grad():
    re_ex, im_ex, _ = problem["exact"](problem["n_level"], t, x)
    y = model(torch.cat([t, x], dim=1))
    re_pr, im_pr = y[:,0:1], y[:,1:2]

print("max|Re exact|:", re_ex.abs().max().item(), " max|Im exact|:", im_ex.abs().max().item())
print("max|Re pred |:", re_pr.abs().max().item(), " max|Im pred |:", im_pr.abs().max().item())
print("ratio exact Im/Re:", (im_ex.abs().max()/re_ex.abs().max()).item())
print("ratio pred  Im/Re:", (im_pr.abs().max()/re_pr.abs().max()).item())
# Out:
# max|Re exact|: 0.7472226023674011  max|Im exact|: 0.07497233897447586
# max|Re pred |: 0.7543120384216309  max|Im pred |: 0.0041246674954891205
# ratio exact Im/Re: 0.10033467411994934
# ratio pred  Im/Re: 0.005468118470162153
