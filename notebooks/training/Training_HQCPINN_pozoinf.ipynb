# %% [markdown]
# # Definición de modelo e implementación
# Generación de caso piloto de PINN en MLP sencilla, y posteriormente aplicación en esquema

# %% [markdown]
# ## Modelo Hibrido

# %% [markdown]
# ### Definición del modelo

# %% [markdown]
# 0. Llamado de modulos de interés

# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

# %%
# Librerias de interés
import torch
import os

import sys

import pennylane as qml

import numpy as np
import matplotlib.pyplot as plt

# %%
# Import of source modules and utils needed
import src.trainer.schrodinger_train as wave_train

from src.utils.logger                   import Logging
from src.utils.plot_loss                import smooth_loss
from src.utils.plot_prediction          import plt_prediction

from src.nn.DVPDESolver                 import DVPDESolver
from src.nn.CVPDESolver                 import CVPDESolver
from src.nn.ClassicalSolver2            import ClassicalSolver2
from src.nn.pde                         import schrodinger_operator

from data.synthetic.schrodinger_dataset import exact_eigenstate

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# 1. Definición de Parametros de entrenamiento

# %%
mode = "hybrid"
num_qubits = 4
output_dim = 2
input_dim = 2
hidden_dim = 50
num_quantum_layers = 2
cutoff_dim = 20
classic_network = [input_dim, hidden_dim, output_dim]

# Input parameters: Iterable
L = 5.0        # dominio espacial [0, L]
T = 0.1        # tiempo final
hbar = 1.0
mass = 1.0
n_level = 0    # nivel (usaremos n=1)
omega  = 1.0
example = 'box'
potential_fn = 0

if example.lower() != 'box':
    potential_fn = f"lambda t, x : 0.5 * {mass} * ({omega}**2) * (x**2)"

# Equation parameters
eq_params = dict(
    example="box",
    L=1.0,
    T=0.2,
    hbar=1.0,
    mass=1.0,
    n_level=1,
)

args = {
    "batch_size": 64,
    "epochs": 2000, 
    "lr": 1E-3,
    "seed": 42,
    "print_every": 1,
    "log_path": "./results/models/checkpoints/schrodinger/qho",
    "input_dim": input_dim,
    "output_dim": output_dim,
    "num_qubits": num_qubits,
    "hidden_dim": hidden_dim,
    "num_quantum_layers": num_quantum_layers,
    "classic_network": classic_network,
    "q_ansatz": "sim_circ_19",  # options: "alternating_layer_tdcnot", "abbas" , farhi , sim_circ_13_half, sim_circ_13 , sim_circ_14_half, sim_circ_14 , sim_circ_15 ,sim_circ_19
    "mode": mode,
    "activation": "null",  # options: "null", "partial_measurement_half" , partial_measurement_x, tanh (Classical)
    "shots": 1,  # Analytical gradients enabled
    "problem": "schrodinger",
    "solver": "Classical",  # options : "CV", "Classical", "DV"
    "device": DEVICE,
    "method": "None",
    "cutoff_dim": cutoff_dim,  # num_qubits >= cutoff_dim
    "class": "CVNeuralNetwork2",  # options CVNeuralNetwork1, CVNeuralNetwork2, CVNeuralNetwork3
    "encoding": "angle",  # options : "ampiltude" , "angle" for DV , none for others
    "eq_params" : eq_params,
    "noise" : False,
}

# %% [markdown]
# 2. Validación de componentes

# %%
log_path = args["log_path"]
logger = Logging(log_path)

# %%
if args["solver"] == "CV":
    model = CVPDESolver(args, logger, DEVICE)
    model.logger.print("Using CV Solver")
elif args["solver"] == "Classical":
    model = ClassicalSolver2(args, logger, DEVICE)
    model.logger.print("Using Classical Solver")
else:
    model = DVPDESolver(args, logger, DEVICE)
    model.logger.print("Using DV Solver")

model.logger.print(f"The settings used:")
for key, value in args.items():
    model.logger.print(f"{key} : {value}")
# Out:
# INFO:src.utils.logger:checkpoint path: self.log_path='./results/models/checkpoints/schrodinger/qho\\2025-12-10_14-18-22-979154'
# INFO:src.utils.logger:Using Classical Solver
# INFO:src.utils.logger:The settings used:
# INFO:src.utils.logger:batch_size : 64
# INFO:src.utils.logger:epochs : 2000
# INFO:src.utils.logger:lr : 0.001
# INFO:src.utils.logger:seed : 42
# INFO:src.utils.logger:print_every : 1
# INFO:src.utils.logger:log_path : ./results/models/checkpoints/schrodinger/qho
# INFO:src.utils.logger:input_dim : 2
# INFO:src.utils.logger:output_dim : 2
# INFO:src.utils.logger:num_qubits : 4
# INFO:src.utils.logger:hidden_dim : 50
# INFO:src.utils.logger:num_quantum_layers : 2
# INFO:src.utils.logger:classic_network : [2, 50, 2]
# INFO:src.utils.logger:q_ansatz : sim_circ_19
# INFO:src.utils.logger:mode : hybrid
# INFO:src.utils.logger:activation : null
# INFO:src.utils.logger:shots : 1
# INFO:src.utils.logger:problem : schrodinger
# INFO:src.utils.logger:solver : Classical
# INFO:src.utils.logger:device : cpu
# INFO:src.utils.logger:method : None
# INFO:src.utils.logger:cutoff_dim : 20
# INFO:src.utils.logger:class : CVNeuralNetwork2
# INFO:src.utils.logger:encoding : angle
# INFO:src.utils.logger:eq_params : {'example': 'box', 'L': 1.0, 'T': 0.2, 'hbar': 1.0, 'mass': 1.0, 'n_level': 1}
# INFO:src.utils.logger:noise : False

# %%
# Definición de tipado para entrenamiento
DTYPE = torch.float32 
torch.set_default_dtype(DTYPE)
torch.manual_seed(0)

# Print total number of parameters
total_params = sum(p.numel() for p in model.parameters())
model.logger.print(f"Total number of parameters: {total_params}")
# Out:
# INFO:src.utils.logger:Total number of parameters: 7902

# %% [markdown]
# ### Entrenamiento del modelo

# %% [markdown]
# 0. Entrenamiento con parametros por defecto

# %%
wave_train.train(model, N_f=2000, N_b=400, N_0=400)
# Out:
# INFO:src.utils.logger:It: 1, Loss: 1.528e-02, Loss_res: 5.481e-03,  Loss_bcs: 4.285e-03, Loss_ut_ics: 1.094e+00, L^2_error: 1.002368e+00, lr: 1.000e-03, Time: 5.30e-02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 2, Loss: 1.169e-02, Loss_res: 4.803e-03,  Loss_bcs: 1.332e-03, Loss_ut_ics: 1.031e+00, L^2_error: 9.948245e-01, lr: 1.000e-03, Time: 1.06e-01
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 3, Loss: 1.072e-02, Loss_res: 4.680e-03,  Loss_bcs: 1.235e-03, Loss_ut_ics: 9.434e-01, L^2_error: 9.962975e-01, lr: 1.000e-03, Time: 2.10e-01
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 4, Loss: 1.115e-02, Loss_res: 4.665e-03,  Loss_bcs: 2.017e-03, Loss_ut_ics: 9.083e-01, L^2_error: 9.997118e-01, lr: 1.000e-03, Time: 2.66e-01
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 5, Loss: 1.168e-02, Loss_res: 4.315e-03,  Loss_bcs: 2.150e-03, Loss_ut_ics: 9.484e-01, L^2_error: 1.001554e+00, lr: 1.000e-03, Time: 3.07e-01
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 6, Loss: 1.082e-02, Loss_res: 3.759e-03,  Loss_bcs: 1.590e-03, Loss_ut_ics: 9.191e-01, L^2_error: 1.001933e+00, lr: 1.000e-03, Time: 3.52e-01
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 7, Loss: 1.096e-02, Loss_res: 3.170e-03,  Loss_bcs: 8.319e-04, Loss_ut_ics: 1.010e+00, L^2_error: 1.001083e+00, lr: 1.000e-03, Time: 4.01e-01
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 8, Loss: 1.039e-02, Loss_res: 2.612e-03,  Loss_bcs: 2.678e-04, Loss_ut_ics: 1.010e+00, L^2_error: 9.995925e-01, lr: 1.000e-03, Time: 4.52e-01
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 9, Loss: 1.032e-02, Loss_res: 2.130e-03,  Loss_bcs: 5.734e-05, Loss_ut_ics: 1.024e+00, L^2_error: 9.984485e-01, lr: 1.000e-03, Time: 4.99e-01
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 10, Loss: 1.026e-02, Loss_res: 1.748e-03,  Loss_bcs: 1.352e-04, Loss_ut_ics: 1.011e+00, L^2_error: 9.983701e-01, lr: 1.000e-03, Time: 5.46e-01
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 11, Loss: 1.036e-02, Loss_res: 1.470e-03,  Loss_bcs: 2.880e-04, Loss_ut_ics: 1.006e+00, L^2_error: 9.991035e-01, lr: 1.000e-03, Time: 5.94e-01
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 12, Loss: 1.046e-02, Loss_res: 1.300e-03,  Loss_bcs: 3.651e-04, Loss_ut_ics: 1.008e+00, L^2_error: 9.999574e-01, lr: 1.000e-03, Time: 6.46e-01
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 13, Loss: 1.113e-02, Loss_res: 1.187e-03,  Loss_bcs: 3.401e-04, Loss_ut_ics: 1.078e+00, L^2_error: 1.000363e+00, lr: 1.000e-03, Time: 6.92e-01
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 14, Loss: 1.013e-02, Loss_res: 1.115e-03,  Loss_bcs: 2.698e-04, Loss_ut_ics: 9.846e-01, L^2_error: 1.000162e+00, lr: 1.000e-03, Time: 7.36e-01
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 15, Loss: 1.012e-02, Loss_res: 1.068e-03,  Loss_bcs: 2.395e-04, Loss_ut_ics: 9.875e-01, L^2_error: 9.993553e-01, lr: 1.000e-03, Time: 7.82e-01
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 16, Loss: 9.504e-03, Loss_res: 1.041e-03,  Loss_bcs: 2.834e-04, Loss_ut_ics: 9.210e-01, L^2_error: 9.982317e-01, lr: 1.000e-03, Time: 8.54e-01
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 17, Loss: 1.004e-02, Loss_res: 1.041e-03,  Loss_bcs: 3.967e-04, Loss_ut_ics: 9.632e-01, L^2_error: 9.972453e-01, lr: 1.000e-03, Time: 9.09e-01
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 18, Loss: 1.004e-02, Loss_res: 1.077e-03,  Loss_bcs: 4.999e-04, Loss_ut_ics: 9.527e-01, L^2_error: 9.966291e-01, lr: 1.000e-03, Time: 9.65e-01
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 19, Loss: 1.067e-02, Loss_res: 1.160e-03,  Loss_bcs: 5.590e-04, Loss_ut_ics: 1.010e+00, L^2_error: 9.965124e-01, lr: 1.000e-03, Time: 1.02e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 20, Loss: 9.980e-03, Loss_res: 1.286e-03,  Loss_bcs: 5.393e-04, Loss_ut_ics: 9.428e-01, L^2_error: 9.970013e-01, lr: 1.000e-03, Time: 1.08e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 21, Loss: 1.047e-02, Loss_res: 1.448e-03,  Loss_bcs: 4.198e-04, Loss_ut_ics: 1.004e+00, L^2_error: 9.977324e-01, lr: 1.000e-03, Time: 1.13e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 22, Loss: 9.840e-03, Loss_res: 1.646e-03,  Loss_bcs: 2.735e-04, Loss_ut_ics: 9.550e-01, L^2_error: 9.984413e-01, lr: 1.000e-03, Time: 1.18e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 23, Loss: 9.514e-03, Loss_res: 1.873e-03,  Loss_bcs: 1.584e-04, Loss_ut_ics: 9.337e-01, L^2_error: 9.989884e-01, lr: 1.000e-03, Time: 1.23e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 24, Loss: 1.012e-02, Loss_res: 2.112e-03,  Loss_bcs: 6.629e-05, Loss_ut_ics: 1.004e+00, L^2_error: 9.990611e-01, lr: 1.000e-03, Time: 1.27e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 25, Loss: 1.002e-02, Loss_res: 2.358e-03,  Loss_bcs: 3.065e-05, Loss_ut_ics: 9.966e-01, L^2_error: 9.987814e-01, lr: 1.000e-03, Time: 1.31e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 26, Loss: 9.892e-03, Loss_res: 2.603e-03,  Loss_bcs: 2.680e-05, Loss_ut_ics: 9.839e-01, L^2_error: 9.984109e-01, lr: 1.000e-03, Time: 1.36e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 27, Loss: 9.615e-03, Loss_res: 2.843e-03,  Loss_bcs: 3.343e-05, Loss_ut_ics: 9.554e-01, L^2_error: 9.981249e-01, lr: 1.000e-03, Time: 1.42e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 28, Loss: 1.143e-02, Loss_res: 3.081e-03,  Loss_bcs: 4.081e-05, Loss_ut_ics: 1.136e+00, L^2_error: 9.979252e-01, lr: 1.000e-03, Time: 1.48e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 29, Loss: 9.802e-03, Loss_res: 3.323e-03,  Loss_bcs: 4.525e-05, Loss_ut_ics: 9.724e-01, L^2_error: 9.980529e-01, lr: 1.000e-03, Time: 1.53e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 30, Loss: 9.748e-03, Loss_res: 3.558e-03,  Loss_bcs: 5.560e-05, Loss_ut_ics: 9.657e-01, L^2_error: 9.984676e-01, lr: 1.000e-03, Time: 1.58e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 31, Loss: 9.110e-03, Loss_res: 3.795e-03,  Loss_bcs: 7.413e-05, Loss_ut_ics: 8.998e-01, L^2_error: 9.990544e-01, lr: 1.000e-03, Time: 1.63e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 32, Loss: 8.919e-03, Loss_res: 4.016e-03,  Loss_bcs: 1.167e-04, Loss_ut_ics: 8.762e-01, L^2_error: 9.996091e-01, lr: 1.000e-03, Time: 1.68e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 33, Loss: 9.763e-03, Loss_res: 4.217e-03,  Loss_bcs: 1.579e-04, Loss_ut_ics: 9.563e-01, L^2_error: 9.997871e-01, lr: 1.000e-03, Time: 1.73e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 34, Loss: 1.009e-02, Loss_res: 4.393e-03,  Loss_bcs: 1.836e-04, Loss_ut_ics: 9.861e-01, L^2_error: 9.994266e-01, lr: 1.000e-03, Time: 1.77e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 35, Loss: 1.039e-02, Loss_res: 4.558e-03,  Loss_bcs: 2.115e-04, Loss_ut_ics: 1.013e+00, L^2_error: 9.987982e-01, lr: 1.000e-03, Time: 1.82e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 36, Loss: 1.017e-02, Loss_res: 4.704e-03,  Loss_bcs: 2.281e-04, Loss_ut_ics: 9.895e-01, L^2_error: 9.983788e-01, lr: 1.000e-03, Time: 1.86e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 37, Loss: 9.345e-03, Loss_res: 4.824e-03,  Loss_bcs: 1.961e-04, Loss_ut_ics: 9.100e-01, L^2_error: 9.984263e-01, lr: 1.000e-03, Time: 1.91e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 38, Loss: 1.006e-02, Loss_res: 4.926e-03,  Loss_bcs: 1.544e-04, Loss_ut_ics: 9.852e-01, L^2_error: 9.988031e-01, lr: 1.000e-03, Time: 1.96e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 39, Loss: 1.013e-02, Loss_res: 5.010e-03,  Loss_bcs: 1.173e-04, Loss_ut_ics: 9.958e-01, L^2_error: 9.993935e-01, lr: 1.000e-03, Time: 2.00e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 40, Loss: 9.958e-03, Loss_res: 5.079e-03,  Loss_bcs: 7.469e-05, Loss_ut_ics: 9.833e-01, L^2_error: 9.997881e-01, lr: 1.000e-03, Time: 2.05e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 41, Loss: 9.842e-03, Loss_res: 5.132e-03,  Loss_bcs: 5.821e-05, Loss_ut_ics: 9.732e-01, L^2_error: 9.999062e-01, lr: 1.000e-03, Time: 2.09e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 42, Loss: 9.631e-03, Loss_res: 5.157e-03,  Loss_bcs: 4.989e-05, Loss_ut_ics: 9.530e-01, L^2_error: 9.997185e-01, lr: 1.000e-03, Time: 2.14e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 43, Loss: 9.641e-03, Loss_res: 5.155e-03,  Loss_bcs: 5.050e-05, Loss_ut_ics: 9.539e-01, L^2_error: 9.993992e-01, lr: 1.000e-03, Time: 2.20e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 44, Loss: 9.887e-03, Loss_res: 5.120e-03,  Loss_bcs: 5.844e-05, Loss_ut_ics: 9.777e-01, L^2_error: 9.991302e-01, lr: 1.000e-03, Time: 2.25e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 45, Loss: 1.062e-02, Loss_res: 5.072e-03,  Loss_bcs: 6.843e-05, Loss_ut_ics: 1.050e+00, L^2_error: 9.988227e-01, lr: 1.000e-03, Time: 2.31e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 46, Loss: 8.869e-03, Loss_res: 5.018e-03,  Loss_bcs: 7.992e-05, Loss_ut_ics: 8.739e-01, L^2_error: 9.987749e-01, lr: 1.000e-03, Time: 2.37e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 47, Loss: 9.763e-03, Loss_res: 4.951e-03,  Loss_bcs: 1.092e-04, Loss_ut_ics: 9.605e-01, L^2_error: 9.989071e-01, lr: 1.000e-03, Time: 2.42e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 48, Loss: 1.054e-02, Loss_res: 4.882e-03,  Loss_bcs: 1.179e-04, Loss_ut_ics: 1.038e+00, L^2_error: 9.989611e-01, lr: 1.000e-03, Time: 2.47e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 49, Loss: 1.008e-02, Loss_res: 4.829e-03,  Loss_bcs: 1.364e-04, Loss_ut_ics: 9.898e-01, L^2_error: 9.988990e-01, lr: 1.000e-03, Time: 2.53e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 50, Loss: 1.007e-02, Loss_res: 4.780e-03,  Loss_bcs: 1.543e-04, Loss_ut_ics: 9.872e-01, L^2_error: 9.988590e-01, lr: 1.000e-03, Time: 2.58e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 51, Loss: 9.707e-03, Loss_res: 4.724e-03,  Loss_bcs: 1.516e-04, Loss_ut_ics: 9.508e-01, L^2_error: 9.988505e-01, lr: 1.000e-03, Time: 2.62e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 52, Loss: 8.849e-03, Loss_res: 4.682e-03,  Loss_bcs: 1.458e-04, Loss_ut_ics: 8.657e-01, L^2_error: 9.990591e-01, lr: 1.000e-03, Time: 2.68e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 53, Loss: 1.007e-02, Loss_res: 4.620e-03,  Loss_bcs: 1.129e-04, Loss_ut_ics: 9.915e-01, L^2_error: 9.990261e-01, lr: 1.000e-03, Time: 2.73e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 54, Loss: 9.759e-03, Loss_res: 4.561e-03,  Loss_bcs: 9.386e-05, Loss_ut_ics: 9.619e-01, L^2_error: 9.988492e-01, lr: 1.000e-03, Time: 2.77e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 55, Loss: 9.361e-03, Loss_res: 4.508e-03,  Loss_bcs: 7.468e-05, Loss_ut_ics: 9.241e-01, L^2_error: 9.986190e-01, lr: 1.000e-03, Time: 2.82e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 56, Loss: 1.013e-02, Loss_res: 4.461e-03,  Loss_bcs: 7.185e-05, Loss_ut_ics: 1.001e+00, L^2_error: 9.983659e-01, lr: 1.000e-03, Time: 2.87e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 57, Loss: 9.530e-03, Loss_res: 4.421e-03,  Loss_bcs: 6.569e-05, Loss_ut_ics: 9.420e-01, L^2_error: 9.983208e-01, lr: 1.000e-03, Time: 2.91e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 58, Loss: 9.276e-03, Loss_res: 4.392e-03,  Loss_bcs: 7.378e-05, Loss_ut_ics: 9.158e-01, L^2_error: 9.985300e-01, lr: 1.000e-03, Time: 2.98e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 59, Loss: 9.911e-03, Loss_res: 4.366e-03,  Loss_bcs: 7.995e-05, Loss_ut_ics: 9.788e-01, L^2_error: 9.988200e-01, lr: 1.000e-03, Time: 3.03e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 60, Loss: 9.818e-03, Loss_res: 4.340e-03,  Loss_bcs: 7.851e-05, Loss_ut_ics: 9.696e-01, L^2_error: 9.989539e-01, lr: 1.000e-03, Time: 3.09e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 61, Loss: 9.915e-03, Loss_res: 4.323e-03,  Loss_bcs: 9.315e-05, Loss_ut_ics: 9.779e-01, L^2_error: 9.989295e-01, lr: 1.000e-03, Time: 3.15e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 62, Loss: 9.631e-03, Loss_res: 4.313e-03,  Loss_bcs: 1.015e-04, Loss_ut_ics: 9.487e-01, L^2_error: 9.987525e-01, lr: 1.000e-03, Time: 3.22e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 63, Loss: 1.000e-02, Loss_res: 4.314e-03,  Loss_bcs: 1.063e-04, Loss_ut_ics: 9.855e-01, L^2_error: 9.984639e-01, lr: 1.000e-03, Time: 3.28e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 64, Loss: 9.444e-03, Loss_res: 4.321e-03,  Loss_bcs: 1.240e-04, Loss_ut_ics: 9.277e-01, L^2_error: 9.985331e-01, lr: 1.000e-03, Time: 3.34e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 65, Loss: 9.911e-03, Loss_res: 4.330e-03,  Loss_bcs: 1.125e-04, Loss_ut_ics: 9.756e-01, L^2_error: 9.987001e-01, lr: 1.000e-03, Time: 3.39e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 66, Loss: 1.041e-02, Loss_res: 4.349e-03,  Loss_bcs: 1.055e-04, Loss_ut_ics: 1.026e+00, L^2_error: 9.987746e-01, lr: 1.000e-03, Time: 3.45e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 67, Loss: 9.752e-03, Loss_res: 4.373e-03,  Loss_bcs: 1.006e-04, Loss_ut_ics: 9.608e-01, L^2_error: 9.989409e-01, lr: 1.000e-03, Time: 3.50e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 68, Loss: 9.943e-03, Loss_res: 4.393e-03,  Loss_bcs: 8.188e-05, Loss_ut_ics: 9.817e-01, L^2_error: 9.989036e-01, lr: 1.000e-03, Time: 3.55e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 69, Loss: 9.560e-03, Loss_res: 4.422e-03,  Loss_bcs: 8.115e-05, Loss_ut_ics: 9.435e-01, L^2_error: 9.988673e-01, lr: 1.000e-03, Time: 3.60e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 70, Loss: 9.614e-03, Loss_res: 4.436e-03,  Loss_bcs: 8.492e-05, Loss_ut_ics: 9.485e-01, L^2_error: 9.989579e-01, lr: 1.000e-03, Time: 3.65e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 71, Loss: 9.909e-03, Loss_res: 4.440e-03,  Loss_bcs: 8.095e-05, Loss_ut_ics: 9.783e-01, L^2_error: 9.990538e-01, lr: 1.000e-03, Time: 3.70e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 72, Loss: 9.753e-03, Loss_res: 4.439e-03,  Loss_bcs: 8.081e-05, Loss_ut_ics: 9.628e-01, L^2_error: 9.990769e-01, lr: 1.000e-03, Time: 3.75e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 73, Loss: 9.728e-03, Loss_res: 4.429e-03,  Loss_bcs: 8.548e-05, Loss_ut_ics: 9.598e-01, L^2_error: 9.990618e-01, lr: 1.000e-03, Time: 3.79e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 74, Loss: 9.544e-03, Loss_res: 4.408e-03,  Loss_bcs: 8.410e-05, Loss_ut_ics: 9.416e-01, L^2_error: 9.989102e-01, lr: 1.000e-03, Time: 3.84e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 75, Loss: 1.000e-02, Loss_res: 4.383e-03,  Loss_bcs: 9.538e-05, Loss_ut_ics: 9.866e-01, L^2_error: 9.987320e-01, lr: 1.000e-03, Time: 3.88e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 76, Loss: 9.556e-03, Loss_res: 4.354e-03,  Loss_bcs: 1.066e-04, Loss_ut_ics: 9.406e-01, L^2_error: 9.988636e-01, lr: 1.000e-03, Time: 3.92e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 77, Loss: 1.010e-02, Loss_res: 4.320e-03,  Loss_bcs: 1.045e-04, Loss_ut_ics: 9.952e-01, L^2_error: 9.990025e-01, lr: 1.000e-03, Time: 3.96e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 78, Loss: 9.969e-03, Loss_res: 4.289e-03,  Loss_bcs: 9.301e-05, Loss_ut_ics: 9.833e-01, L^2_error: 9.989271e-01, lr: 1.000e-03, Time: 4.01e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 79, Loss: 9.608e-03, Loss_res: 4.261e-03,  Loss_bcs: 9.237e-05, Loss_ut_ics: 9.473e-01, L^2_error: 9.987504e-01, lr: 1.000e-03, Time: 4.10e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 80, Loss: 9.912e-03, Loss_res: 4.243e-03,  Loss_bcs: 9.690e-05, Loss_ut_ics: 9.772e-01, L^2_error: 9.986041e-01, lr: 1.000e-03, Time: 4.16e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 81, Loss: 1.028e-02, Loss_res: 4.224e-03,  Loss_bcs: 9.458e-05, Loss_ut_ics: 1.014e+00, L^2_error: 9.984933e-01, lr: 1.000e-03, Time: 4.20e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 82, Loss: 1.028e-02, Loss_res: 4.214e-03,  Loss_bcs: 9.658e-05, Loss_ut_ics: 1.014e+00, L^2_error: 9.984922e-01, lr: 1.000e-03, Time: 4.25e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 83, Loss: 9.618e-03, Loss_res: 4.217e-03,  Loss_bcs: 9.254e-05, Loss_ut_ics: 9.483e-01, L^2_error: 9.986933e-01, lr: 1.000e-03, Time: 4.29e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 84, Loss: 9.667e-03, Loss_res: 4.216e-03,  Loss_bcs: 8.940e-05, Loss_ut_ics: 9.535e-01, L^2_error: 9.988976e-01, lr: 1.000e-03, Time: 4.34e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 85, Loss: 1.046e-02, Loss_res: 4.220e-03,  Loss_bcs: 8.550e-05, Loss_ut_ics: 1.033e+00, L^2_error: 9.987766e-01, lr: 1.000e-03, Time: 4.38e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 86, Loss: 9.574e-03, Loss_res: 4.237e-03,  Loss_bcs: 9.195e-05, Loss_ut_ics: 9.440e-01, L^2_error: 9.986691e-01, lr: 1.000e-03, Time: 4.42e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 87, Loss: 9.891e-03, Loss_res: 4.250e-03,  Loss_bcs: 9.462e-05, Loss_ut_ics: 9.754e-01, L^2_error: 9.986039e-01, lr: 1.000e-03, Time: 4.47e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 88, Loss: 9.272e-03, Loss_res: 4.268e-03,  Loss_bcs: 1.035e-04, Loss_ut_ics: 9.126e-01, L^2_error: 9.988275e-01, lr: 1.000e-03, Time: 4.51e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 89, Loss: 9.571e-03, Loss_res: 4.265e-03,  Loss_bcs: 9.495e-05, Loss_ut_ics: 9.433e-01, L^2_error: 9.991003e-01, lr: 1.000e-03, Time: 4.57e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 90, Loss: 9.901e-03, Loss_res: 4.260e-03,  Loss_bcs: 8.659e-05, Loss_ut_ics: 9.772e-01, L^2_error: 9.990085e-01, lr: 1.000e-03, Time: 4.63e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 91, Loss: 9.900e-03, Loss_res: 4.259e-03,  Loss_bcs: 8.506e-05, Loss_ut_ics: 9.772e-01, L^2_error: 9.986445e-01, lr: 1.000e-03, Time: 4.68e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 92, Loss: 1.006e-02, Loss_res: 4.259e-03,  Loss_bcs: 8.949e-05, Loss_ut_ics: 9.926e-01, L^2_error: 9.983187e-01, lr: 1.000e-03, Time: 4.74e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 93, Loss: 1.039e-02, Loss_res: 4.267e-03,  Loss_bcs: 9.373e-05, Loss_ut_ics: 1.025e+00, L^2_error: 9.981892e-01, lr: 1.000e-03, Time: 4.78e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 94, Loss: 9.633e-03, Loss_res: 4.287e-03,  Loss_bcs: 9.948e-05, Loss_ut_ics: 9.490e-01, L^2_error: 9.985552e-01, lr: 1.000e-03, Time: 4.83e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 95, Loss: 9.611e-03, Loss_res: 4.314e-03,  Loss_bcs: 1.009e-04, Loss_ut_ics: 9.467e-01, L^2_error: 9.991060e-01, lr: 1.000e-03, Time: 4.87e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 96, Loss: 9.617e-03, Loss_res: 4.338e-03,  Loss_bcs: 9.326e-05, Loss_ut_ics: 9.481e-01, L^2_error: 9.993687e-01, lr: 1.000e-03, Time: 4.91e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 97, Loss: 1.000e-02, Loss_res: 4.355e-03,  Loss_bcs: 9.406e-05, Loss_ut_ics: 9.865e-01, L^2_error: 9.991733e-01, lr: 1.000e-03, Time: 4.95e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 98, Loss: 1.002e-02, Loss_res: 4.355e-03,  Loss_bcs: 8.847e-05, Loss_ut_ics: 9.883e-01, L^2_error: 9.986253e-01, lr: 1.000e-03, Time: 5.00e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 99, Loss: 9.533e-03, Loss_res: 4.351e-03,  Loss_bcs: 8.733e-05, Loss_ut_ics: 9.402e-01, L^2_error: 9.982531e-01, lr: 1.000e-03, Time: 5.04e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 100, Loss: 9.712e-03, Loss_res: 4.346e-03,  Loss_bcs: 9.588e-05, Loss_ut_ics: 9.572e-01, L^2_error: 9.984038e-01, lr: 1.000e-03, Time: 5.09e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 101, Loss: 9.622e-03, Loss_res: 4.349e-03,  Loss_bcs: 8.439e-05, Loss_ut_ics: 9.494e-01, L^2_error: 9.987756e-01, lr: 1.000e-03, Time: 5.15e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 102, Loss: 9.712e-03, Loss_res: 4.364e-03,  Loss_bcs: 8.056e-05, Loss_ut_ics: 9.588e-01, L^2_error: 9.989641e-01, lr: 1.000e-03, Time: 5.19e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 103, Loss: 1.018e-02, Loss_res: 4.384e-03,  Loss_bcs: 8.718e-05, Loss_ut_ics: 1.005e+00, L^2_error: 9.987851e-01, lr: 1.000e-03, Time: 5.25e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 104, Loss: 9.654e-03, Loss_res: 4.411e-03,  Loss_bcs: 8.866e-05, Loss_ut_ics: 9.521e-01, L^2_error: 9.984827e-01, lr: 1.000e-03, Time: 5.29e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 105, Loss: 1.039e-02, Loss_res: 4.428e-03,  Loss_bcs: 1.037e-04, Loss_ut_ics: 1.024e+00, L^2_error: 9.983283e-01, lr: 1.000e-03, Time: 5.33e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 106, Loss: 9.731e-03, Loss_res: 4.464e-03,  Loss_bcs: 1.083e-04, Loss_ut_ics: 9.578e-01, L^2_error: 9.985207e-01, lr: 1.000e-03, Time: 5.37e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 107, Loss: 9.844e-03, Loss_res: 4.499e-03,  Loss_bcs: 1.182e-04, Loss_ut_ics: 9.681e-01, L^2_error: 9.991629e-01, lr: 1.000e-03, Time: 5.42e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 108, Loss: 9.360e-03, Loss_res: 4.516e-03,  Loss_bcs: 1.013e-04, Loss_ut_ics: 9.213e-01, L^2_error: 9.996300e-01, lr: 1.000e-03, Time: 5.46e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 109, Loss: 9.700e-03, Loss_res: 4.509e-03,  Loss_bcs: 8.822e-05, Loss_ut_ics: 9.566e-01, L^2_error: 9.994889e-01, lr: 1.000e-03, Time: 5.50e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 110, Loss: 1.003e-02, Loss_res: 4.479e-03,  Loss_bcs: 7.506e-05, Loss_ut_ics: 9.911e-01, L^2_error: 9.986295e-01, lr: 1.000e-03, Time: 5.55e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 111, Loss: 1.066e-02, Loss_res: 4.442e-03,  Loss_bcs: 7.940e-05, Loss_ut_ics: 1.053e+00, L^2_error: 9.977195e-01, lr: 1.000e-03, Time: 5.60e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 112, Loss: 9.939e-03, Loss_res: 4.424e-03,  Loss_bcs: 9.784e-05, Loss_ut_ics: 9.797e-01, L^2_error: 9.977968e-01, lr: 1.000e-03, Time: 5.66e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 113, Loss: 9.736e-03, Loss_res: 4.416e-03,  Loss_bcs: 9.800e-05, Loss_ut_ics: 9.594e-01, L^2_error: 9.986958e-01, lr: 1.000e-03, Time: 5.71e+00
# ...
# INFO:src.utils.logger:It: 1964, Loss: 5.660e-04, Loss_res: 2.225e-02,  Loss_bcs: 1.332e-04, Loss_ut_ics: 2.103e-02, L^2_error: 1.504052e-01, lr: 1.000e-03, Time: 1.11e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 1965, Loss: 5.821e-04, Loss_res: 2.187e-02,  Loss_bcs: 1.329e-04, Loss_ut_ics: 2.305e-02, L^2_error: 1.432328e-01, lr: 1.000e-03, Time: 1.11e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 1966, Loss: 5.869e-04, Loss_res: 2.067e-02,  Loss_bcs: 1.835e-04, Loss_ut_ics: 1.967e-02, L^2_error: 1.533906e-01, lr: 1.000e-03, Time: 1.11e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 1967, Loss: 5.729e-04, Loss_res: 1.960e-02,  Loss_bcs: 1.644e-04, Loss_ut_ics: 2.125e-02, L^2_error: 1.443268e-01, lr: 1.000e-03, Time: 1.11e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 1968, Loss: 5.239e-04, Loss_res: 1.862e-02,  Loss_bcs: 1.353e-04, Loss_ut_ics: 2.024e-02, L^2_error: 1.445720e-01, lr: 1.000e-03, Time: 1.11e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 1969, Loss: 5.435e-04, Loss_res: 1.961e-02,  Loss_bcs: 1.567e-04, Loss_ut_ics: 1.908e-02, L^2_error: 1.521890e-01, lr: 1.000e-03, Time: 1.11e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 1970, Loss: 5.772e-04, Loss_res: 1.933e-02,  Loss_bcs: 1.616e-04, Loss_ut_ics: 2.223e-02, L^2_error: 1.400596e-01, lr: 1.000e-03, Time: 1.11e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 1971, Loss: 6.037e-04, Loss_res: 2.006e-02,  Loss_bcs: 2.050e-04, Loss_ut_ics: 1.982e-02, L^2_error: 1.495510e-01, lr: 1.000e-03, Time: 1.11e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 1972, Loss: 6.223e-04, Loss_res: 2.061e-02,  Loss_bcs: 2.100e-04, Loss_ut_ics: 2.062e-02, L^2_error: 1.421934e-01, lr: 1.000e-03, Time: 1.11e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 1973, Loss: 6.450e-04, Loss_res: 2.289e-02,  Loss_bcs: 2.137e-04, Loss_ut_ics: 2.024e-02, L^2_error: 1.444218e-01, lr: 1.000e-03, Time: 1.12e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 1974, Loss: 5.450e-04, Loss_res: 2.023e-02,  Loss_bcs: 1.490e-04, Loss_ut_ics: 1.938e-02, L^2_error: 1.426855e-01, lr: 1.000e-03, Time: 1.12e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 1975, Loss: 5.846e-04, Loss_res: 2.103e-02,  Loss_bcs: 1.656e-04, Loss_ut_ics: 2.087e-02, L^2_error: 1.466395e-01, lr: 1.000e-03, Time: 1.12e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 1976, Loss: 5.642e-04, Loss_res: 2.173e-02,  Loss_bcs: 1.376e-04, Loss_ut_ics: 2.093e-02, L^2_error: 1.393158e-01, lr: 1.000e-03, Time: 1.12e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 1977, Loss: 5.211e-04, Loss_res: 2.022e-02,  Loss_bcs: 1.372e-04, Loss_ut_ics: 1.817e-02, L^2_error: 1.422978e-01, lr: 1.000e-03, Time: 1.12e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 1978, Loss: 5.412e-04, Loss_res: 2.230e-02,  Loss_bcs: 1.364e-04, Loss_ut_ics: 1.818e-02, L^2_error: 1.424686e-01, lr: 1.000e-03, Time: 1.12e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 1979, Loss: 5.287e-04, Loss_res: 1.977e-02,  Loss_bcs: 1.333e-04, Loss_ut_ics: 1.978e-02, L^2_error: 1.380405e-01, lr: 1.000e-03, Time: 1.12e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 1980, Loss: 5.093e-04, Loss_res: 1.984e-02,  Loss_bcs: 1.270e-04, Loss_ut_ics: 1.839e-02, L^2_error: 1.419508e-01, lr: 1.000e-03, Time: 1.12e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 1981, Loss: 5.326e-04, Loss_res: 1.983e-02,  Loss_bcs: 1.459e-04, Loss_ut_ics: 1.884e-02, L^2_error: 1.432064e-01, lr: 1.000e-03, Time: 1.12e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 1982, Loss: 5.680e-04, Loss_res: 2.000e-02,  Loss_bcs: 1.676e-04, Loss_ut_ics: 2.004e-02, L^2_error: 1.293066e-01, lr: 1.000e-03, Time: 1.12e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 1983, Loss: 6.931e-04, Loss_res: 2.012e-02,  Loss_bcs: 3.130e-04, Loss_ut_ics: 1.789e-02, L^2_error: 1.496806e-01, lr: 1.000e-03, Time: 1.12e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 1984, Loss: 8.080e-04, Loss_res: 2.094e-02,  Loss_bcs: 3.971e-04, Loss_ut_ics: 2.015e-02, L^2_error: 1.293340e-01, lr: 1.000e-03, Time: 1.12e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 1985, Loss: 8.539e-04, Loss_res: 2.149e-02,  Loss_bcs: 4.820e-04, Loss_ut_ics: 1.570e-02, L^2_error: 1.437209e-01, lr: 1.000e-03, Time: 1.12e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 1986, Loss: 7.320e-04, Loss_res: 2.189e-02,  Loss_bcs: 3.342e-04, Loss_ut_ics: 1.788e-02, L^2_error: 1.338927e-01, lr: 1.000e-03, Time: 1.12e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 1987, Loss: 4.842e-04, Loss_res: 1.926e-02,  Loss_bcs: 1.180e-04, Loss_ut_ics: 1.737e-02, L^2_error: 1.319834e-01, lr: 1.000e-03, Time: 1.13e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 1988, Loss: 5.678e-04, Loss_res: 1.915e-02,  Loss_bcs: 2.085e-04, Loss_ut_ics: 1.678e-02, L^2_error: 1.458000e-01, lr: 1.000e-03, Time: 1.13e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 1989, Loss: 8.389e-04, Loss_res: 1.966e-02,  Loss_bcs: 4.592e-04, Loss_ut_ics: 1.830e-02, L^2_error: 1.228284e-01, lr: 1.000e-03, Time: 1.13e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 1990, Loss: 1.002e-03, Loss_res: 1.881e-02,  Loss_bcs: 6.562e-04, Loss_ut_ics: 1.576e-02, L^2_error: 1.521751e-01, lr: 1.000e-03, Time: 1.13e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 1991, Loss: 1.007e-03, Loss_res: 2.099e-02,  Loss_bcs: 6.006e-04, Loss_ut_ics: 1.967e-02, L^2_error: 1.224364e-01, lr: 1.000e-03, Time: 1.13e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 1992, Loss: 8.989e-04, Loss_res: 1.867e-02,  Loss_bcs: 5.647e-04, Loss_ut_ics: 1.475e-02, L^2_error: 1.452502e-01, lr: 1.000e-03, Time: 1.13e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 1993, Loss: 7.436e-04, Loss_res: 2.032e-02,  Loss_bcs: 3.640e-04, Loss_ut_ics: 1.764e-02, L^2_error: 1.299787e-01, lr: 1.000e-03, Time: 1.13e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 1994, Loss: 6.035e-04, Loss_res: 2.067e-02,  Loss_bcs: 2.127e-04, Loss_ut_ics: 1.840e-02, L^2_error: 1.308285e-01, lr: 1.000e-03, Time: 1.13e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 1995, Loss: 4.942e-04, Loss_res: 1.716e-02,  Loss_bcs: 1.560e-04, Loss_ut_ics: 1.666e-02, L^2_error: 1.412410e-01, lr: 1.000e-03, Time: 1.13e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 1996, Loss: 5.584e-04, Loss_res: 1.935e-02,  Loss_bcs: 1.993e-04, Loss_ut_ics: 1.656e-02, L^2_error: 1.268635e-01, lr: 1.000e-03, Time: 1.13e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 1997, Loss: 7.245e-04, Loss_res: 1.960e-02,  Loss_bcs: 3.686e-04, Loss_ut_ics: 1.599e-02, L^2_error: 1.380130e-01, lr: 1.000e-03, Time: 1.13e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 1998, Loss: 7.490e-04, Loss_res: 1.918e-02,  Loss_bcs: 3.774e-04, Loss_ut_ics: 1.798e-02, L^2_error: 1.244681e-01, lr: 1.000e-03, Time: 1.13e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 1999, Loss: 6.310e-04, Loss_res: 1.913e-02,  Loss_bcs: 2.935e-04, Loss_ut_ics: 1.461e-02, L^2_error: 1.413608e-01, lr: 1.000e-03, Time: 1.13e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth
# INFO:src.utils.logger:It: 2000, Loss: 6.067e-04, Loss_res: 2.146e-02,  Loss_bcs: 2.276e-04, Loss_ut_ics: 1.645e-02, L^2_error: 1.233721e-01, lr: 1.000e-03, Time: 1.13e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model.pth
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/schrodinger/qho\2025-12-10_14-18-22-979154\model_weights.pth

# %% [markdown]
# 1. Métricas de entrenamiento

# %%
# Loss history plot 
plt.semilogy(range(len(model.loss_history)), model.loss_history)
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Training Loss Over Epochs")
plt.grid()

file_path = os.path.join(model.log_path, "loss_history.pdf")
plt.savefig(file_path, bbox_inches="tight")
plt.show()

plt.close(
    "all",
)

# %%
# Loss history plot 
plt.semilogy(range(len(model.loss_history)), smooth_loss(model.loss_history))
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Training Loss Over Epochs")
plt.grid()

file_path = os.path.join(model.log_path, "loss_history_smooth.pdf")
plt.savefig(file_path, bbox_inches="tight")
plt.show()

plt.close(
    "all",
)

# %%
# Loss vs Error 
plt.figure()
plt.plot(smooth_loss(model.loss_history), smooth_loss(model.l2_rel_history), "-s", label="Error L2 relativo ")
plt.xscale("log")
plt.yscale("log")
plt.xlabel("Loss")
plt.ylabel("Error L2")
plt.title("Loss vs Error L2 ")
plt.grid(True, which="both", ls="--", lw=0.5)
plt.legend()
plt.tight_layout()
plt.show()

# Saving of graph 
file_path = os.path.join(model.log_path, "LossVsError.pdf")
plt.savefig(file_path, bbox_inches="tight")
plt.show(); plt.close("all")

# %% [markdown]
# ### Cargado de modelos

# %% [markdown]
# 0. Cargado de parametros de modelos

# %%
# Generación de dirección
# - Original model trainining it's ./results/models/checkpoints/schrodinger/qho/2025-09-16_19-49-40-397660 : 33 epochs
#                                - ./results/models/checkpoints/schrodinger/qho/2025-09-16_23-56-29-184043 : 240 epochs
#                                - ./results/models/checkpoints/schrodinger/qho/2025-09-17_05-32-12-177643 : Partial eval
#                                - ./results/models/checkpoints/schrodinger/qho/2025-09-18_23-15-25-067856 : 613 epochs
#                                - ./results/models/checkpoints/schrodinger/qho/2025-09-19_06-50-08-412171 : Partial eval
#                                - ./results/models/checkpoints/schrodinger/qho/2025-09-19_12-51-35-995760 : 726 epochs
#                                - ./results/models/checkpoints/schrodinger/qho/2025-09-19_15-21-51-366423 : Partial eval

#                                - ./results/models/checkpoints/schrodinger/qho/2025-09-19_08-02-15-211102 : 266 epochs
#                                - ./results/models/checkpoints/schrodinger/qho/2025-09-19_11-42-54-648031 : Partial eval
#                                - ./results/models/checkpoints/schrodinger/qho/2025-09-19_15-24-52-373878 : 1000 epochs

model_dir = "./results/models/checkpoints/schrodinger/qho/2025-09-19_19-00-03-567204"

# Cargado de versiones de los modelos
model_path = os.path.join(model_dir, "model_weights.pth")

# Load the state dictionary into the model
model.load_state_dict(torch.load(model_path, weights_only=True))

# Set the model to evaluation mode (important for inference)
model.eval()
# Out:
# DVPDESolver(
#   (preprocessor): Sequential(
#     (0): Linear(in_features=2, out_features=30, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=30, out_features=5, bias=True)
#   )
#   (postprocessor): Sequential(
#     (0): Linear(in_features=5, out_features=30, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=30, out_features=2, bias=True)
#   )
#   (activation): Tanh()
#   (quantum_layer): DVQuantumLayer()
#   (loss_fn): MSELoss()
# )

# %% [markdown]
# ### Pruebas de predicción

# %% [markdown]
# 0. Definición de parametros

# %%
# Parametros físicos del dominio
L       = model.args['eq_params']['L']          # dominio espacial [0, L]
T       = model.args['eq_params']['T']          # tiempo final
hbar    = model.args['eq_params']['hbar'] 
mass    = model.args['eq_params']['mass']
n_level = model.args['eq_params']['n_level']    # nivel del pozo (usaremos n=1)

example = model.args['eq_params']['example']

# Definición por defecto de parametros
potential_fn = 0; omega = 1.0

# Cargado según ejemplos de uso
if model.args['eq_params']['example'].lower() == 'ho':             # Oscilador armonico

    potential_fn = eval(model.args['eq_params']['potential_fn'])   # Función de potencial
    omega        = model.args['eq_params']['omega']                # Frecuencia natural

potential_fn = eval(model.args['eq_params']['potential_fn'])
omega = 1.0; example = 'ho'
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[44], line 19
#      16     potential_fn = eval(model.args['eq_params']['potential_fn'])   # Función de potencial
#      17     omega        = model.args['eq_params']['omega']                # Frecuencia natural
# ---> 19 potential_fn = eval(model.args['eq_params']['potential_fn'])
#      20 omega = 1.0; example = 'ho'
#
# KeyError: 'potential_fn'

# %% [markdown]
# 1. Generación de datos

# %%
# settings
number_of_points = 50

# mesh of t - x evaluation
# - Create mesh grid with float32
if example.lower() == 'ho':
    t = np.linspace(0, T, number_of_points, dtype=np.float32)[:, None]
    x = np.linspace(-L, L, number_of_points, dtype=np.float32)[:, None]
else:
    t = np.linspace(0, T, number_of_points, dtype=np.float32)[:, None]
    x = torch.linspace(0.0, L, number_of_points, device=DEVICE, dtype=DTYPE).unsqueeze(1)

t, x = np.meshgrid(t, x);

t = t.flatten()[:, None]
x = x.flatten()[:, None]

# - Generation of torch elements
t_eval = torch.from_numpy(t); x_eval = torch.from_numpy(x)

# - Generation of input argument
X_star = (
    torch.hstack(
        (torch.from_numpy(t.flatten()[:, None]), torch.from_numpy(x.flatten()[:, None]))
    )
    .to(DEVICE)
    .to(torch.float32)
)

X = X_star.cpu().detach().numpy()

# %%
qml.draw_mpl(model.quantum_layer.circuit)(model.preprocessor(X_star[0, 0:2]));

# %%
# Predictions over values
with torch.no_grad():
    psi_pred = model(torch.cat((t_eval, x_eval), dim=1))
    psi_r_pred = psi_pred[:, 0:1]
    psi_i_pred = psi_pred[:, 1:2]
    mod2_pred = (psi_r_pred**2 + psi_i_pred**2).squeeze(1).cpu().numpy()

    psi_r_true, psi_i_true, En = exact_eigenstate(n_level, t_eval, x_eval, L=L, mass=mass, hbar=hbar, omega=omega, example=example)
    mod2_true = (psi_r_true**2 + psi_i_true**2).squeeze(1).cpu().numpy()

# %% [markdown]
# 2. Métricas de predicción

# %%
def magnitude_mean(y_pred_r, y_true_r, y_pred_i, y_true_i):

    # Squared differences for each value
    mse_r = (y_pred_r.cpu().detach().numpy() - y_true_r.cpu().detach().numpy())**2
    mse_i = (y_pred_i.cpu().detach().numpy() - y_true_i.cpu().detach().numpy())**2

    # Magnitude mse + norm
    mse = np.sqrt(mse_r + mse_i).mean()

    return mse

# %%
# Routine plots:
plt_prediction(
    logger,
    X,
    psi_r_true.cpu().detach().numpy(),
    psi_r_pred.cpu().detach().numpy(),
    psi_i_true.cpu().detach().numpy(),
    psi_i_pred.cpu().detach().numpy(),
)

# %%
# Gráfico 1: |psi|^2 en t=T (PINN vs exacto)
plt.figure()
plt.plot(x_eval.squeeze(1).cpu().numpy(), mod2_true, label="|ψ|^2 exacto")
plt.plot(x_eval.squeeze(1).cpu().numpy(), mod2_pred, "--", label="|ψ|^2 PINN")
plt.title(f"|ψ(x,T)|^2 en pozo infinito (n={n_level})")
plt.xlabel("x")
plt.ylabel("|ψ|^2")
plt.legend()
plt.grid()

# Saving of solution comparison plot 
file_path = os.path.join(model.log_path, "solution_plot.pdf")
plt.savefig(file_path, bbox_inches="tight")
plt.show(); plt.close("all")

# %%
# Gráfico 2: error absoluto en |psi|^2
plt.figure()
abs_err = np.abs(mod2_pred - mod2_true)
plt.plot(x_eval.squeeze(1).cpu().numpy(), abs_err, label="Error absoluto")
plt.title("Error absoluto en |ψ(x,T)|^2")
plt.xlabel("x")
plt.ylabel("Error")
plt.legend()
plt.grid()

# Saving of solution comparison plot 
file_path = os.path.join(model.log_path, "error_plot.pdf")
plt.savefig(file_path, bbox_inches="tight")
plt.show(); plt.close("all")
