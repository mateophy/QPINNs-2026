# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

# %%
import torch
import matplotlib.pyplot as plt
from pathlib import Path
import sys

# Asegura imports desde la raíz del repo (ajusta si tu notebook está en otra carpeta)
ROOT = Path().resolve()
if not (ROOT / "src").exists() and (ROOT.parent / "src").exists():
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT))

device = "cuda" if torch.cuda.is_available() else "cpu"
dtype  = "float32"  # DV suele ser más estable y rápido en float32 en tu repo

torch.manual_seed(0)
if device == "cuda":
    torch.cuda.manual_seed_all(0)

print("device:", device, " dtype:", dtype, " ROOT:", ROOT)
# Out:
# device: cpu  dtype: float32  ROOT: C:\Users\mateo garcia\Documents\A master\Tesis\QPINNs-2025

# %%
import importlib

import src.trainer.schrodinger_train as sch_train
import src.nn.DVPDESolver as dv_solver_mod

importlib.reload(sch_train)
importlib.reload(dv_solver_mod)

from src.trainer.schrodinger_train import train
from src.nn.DVPDESolver import DVPDESolver

from src.problems.schrodinger import build_eq_params, sanity_check
from src.problems.schrodinger.problem import build_problem
from src.utils.logger import Logging

print("Imports OK.")
# Out:
# Imports OK.

# %%
# --- Pozo infinito (box) ---
eq_params = build_eq_params(
    "box",
    L=1.0,
    T=0.2,         # buen T para que Im no sea pequeña
    n_level=1,     # modo n=1
    mass=1.0,
    hbar=1.0,
    num_grid=800,  # para exact/diagnóstico
)

san = sanity_check(eq_params)
print("eq_params:", eq_params)
print("sanity:", san)
# Out:
# eq_params: {'example': 'box', 'L': 1.0, 'T': 0.2, 'mass': 1.0, 'hbar': 1.0, 'n_level': 1, 'x_min': 0.0, 'x_max': 1.0, 'omega': 1.0, 'V0': 50.0, 'barrier_width': 0.2, 'x_center': 0.5, 'num_grid': 800}
# sanity: {'V_min': 0.0, 'V_max': 0.0, 'psi0_norm': 0.9974968671630001, 'psiT_norm': 0.9974968671630003}

# %%
args = {
    "eq_params": eq_params,
    "device": device,
    "dtype": dtype,
    "problem": "schrodinger",
    "hard_bc": True,
    "hard_bc_power": 1.0,

    # training
    "epochs": 600,        # smoke razonable; sube a 1500-3000 si quieres
    "lr": 1e-3,
    "batch_size": 64,
    "print_every": 50,

    # pesos base
    "w_pde": 1.0,
    "w_bc":  0.1,        # box necesita BC fuerte (psi=0 en x=0,L)
    "w_ic":  250.0,
    "w_norm": 5.0,

    # NUEVO: ayudar a que Im no se "ignore" (generalmente mejora DV)
    "w_pde_i": 10.0,
    "w_bc_i":  1.0,
    "w_ic_i":  5.0,

    # warmup/curriculum
    "warmup_epochs": 150,
    "ic_grid": True,      # IC sobre malla (más estable)
    "N_norm": 400,
    "N_val": 400,

    # DV (circuito)
    "num_qubits": 4,
    "num_quantum_layers": 2,
    "shots": None,
    "noise": False,
    "encoding": "angle",
    "q_ansatz": "sim_circ_19",

    # red híbrida
    "classic_network": [2, 64, 2],  # input=(t,x), hidden=64, output=(Re,Im)

    # performance (MUY recomendado en DV)
    "pde_chunk_size": 64,  # chunk para residual (reduce costo / memoria)
    "l2_every": 10,         # calcula L2 cada 5 épocas (acelera)
}

logger = Logging("./results/models/checkpoints/smoke_schrodinger", "box_DV")
model = DVPDESolver(args, logger, device=torch.device(device))
model.args = args
model.draw_quantum_circuit_flag = False  # evita overhead de dibujo

print("DV model built.")
# Out:
# DV model built.

# %%
param_dtype = next(model.parameters()).dtype
param_device = next(model.parameters()).device

t_test = torch.rand(8, 1, device=param_device, dtype=param_dtype) * eq_params["T"]
x_test = torch.rand(8, 1, device=param_device, dtype=param_dtype) * (eq_params["x_max"] - eq_params["x_min"]) + eq_params["x_min"]

y = model(torch.cat([t_test, x_test], dim=1))
print("forward ok ->", y.shape, y.dtype, y.device)
# Out:
# forward ok -> torch.Size([8, 2]) torch.float32 cpu

# %%
import torch
import pennylane as qml
import matplotlib.pyplot as plt

ql = model.quantum_layer

# Encontrar el QNode (ya viste que está en quantum_layer.circuit)
qnode = getattr(ql, "qnode", None)
if qnode is None:
    for name, val in vars(ql).items():
        if isinstance(val, qml.QNode):
            print(f"QNode encontrado en quantum_layer.{name}")
            qnode = val
            break
if qnode is None:
    raise RuntimeError("No encontré un QNode dentro de model.quantum_layer")

# Input para dibujar (ajusta longitud según tu circuito)
dev = next(model.parameters()).device
dt  = next(model.parameters()).dtype

# Prueba con 4 (tu num_qubits=4); si falla, baja a 2.
n = model.args.get("num_qubits", 4) if hasattr(model, "args") else 4
x_draw = torch.zeros(n, device=dev, dtype=dt)
if n >= 2:
    x_draw[0] = 0.0  # t
    x_draw[1] = 0.0  # x

# 1) ASCII
try:
    drawer_txt = qml.draw(qnode)     # <- sin expansion_strategy
    print(drawer_txt(x_draw))
except Exception as e:
    print("No pude dibujar en ASCII con ese x_draw:", repr(e))
    print("Probando con vector de 2 entradas...")
    x2 = torch.tensor([0.0, 0.0], device=dev, dtype=dt)
    drawer_txt = qml.draw(qnode)
    print(drawer_txt(x2))

# 2) Figura (matplotlib)
try:
    drawer_fig = qml.draw_mpl(qnode) # <- sin expansion_strategy
    fig, ax = drawer_fig(x_draw)
    plt.show()
except Exception as e:
    print("No pude dibujar con draw_mpl con ese x_draw:", repr(e))
    print("Probando con vector de 2 entradas...")
    x2 = torch.tensor([0.0, 0.0], device=dev, dtype=dt)
    drawer_fig = qml.draw_mpl(qnode)
    fig, ax = drawer_fig(x2)
    plt.show()
# Out:
# QNode encontrado en quantum_layer.circuit
# 0: ─╭AngleEmbedding(M0)──RX(1.52)───RZ(-0.29)─╭||─╭X──────────────╭●──────────RX(0.09)─ ···
# 1: ─├AngleEmbedding(M0)──RX(-0.25)──RZ(0.08)──├||─│─────╭●────────╰X──────────RX(0.70)─ ···
# 2: ─├AngleEmbedding(M0)──RX(-0.21)──RZ(-0.19)─├||─│──╭●─╰X─────────RX(-0.17)──RZ(-0.09) ···
# 3: ─╰AngleEmbedding(M0)──RX(0.78)───RZ(0.21)──╰||─╰●─╰X──RX(0.62)──RZ(0.36)──────────── ···
#
# 0: ··· ──RZ(-0.46)─╭||─╭X───────╭●─┤  <Z>
# 1: ··· ──RZ(-0.73)─├||─│─────╭●─╰X─┤  <Z>
# 2: ··· ────────────├||─│──╭●─╰X────┤  <Z>
# 3: ··· ────────────╰||─╰●─╰X───────┤  <Z>
#
# M0 =
# tensor([0., 0., 0., 0.])

# %%
# tamaños recomendados para DV (no tan grandes al inicio)
train(model, N_f=768, N_b=0, N_0=256)
# Out:
# INFO:src.utils.logger:It: 1, Loss: 2.138e+02, Loss_res: 2.200e+00,  Loss_bcs: 0.000e+00, Loss_ut_ics: 8.359e-01, Loss_norm: 9.677e-01, Loss_gauge: 0.000e+00, w_pde: 6.67e-03, L^2_error: 8.774e-01, lr: 1.000e-03, Time: 5.18e+00
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2026-02-03_15-23-49-172771_box_DV\model.pth
# INFO:src.utils.logger:Model weights saved to ./results/models/checkpoints/smoke_schrodinger\2026-02-03_15-23-49-172771_box_DV\model_weights.pth
# INFO:src.utils.logger:It: 50, Loss: 1.243e+01, Loss_res: 3.324e+01,  Loss_bcs: 0.000e+00, Loss_ut_ics: 5.243e-03, Loss_norm: 8.573e-03, Loss_gauge: 0.000e+00, w_pde: 3.33e-01, L^2_error: 9.656e-01, lr: 1.000e-03, Time: 2.38e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2026-02-03_15-23-49-172771_box_DV\model.pth
# INFO:src.utils.logger:Model weights saved to ./results/models/checkpoints/smoke_schrodinger\2026-02-03_15-23-49-172771_box_DV\model_weights.pth
# INFO:src.utils.logger:It: 100, Loss: 1.726e+01, Loss_res: 2.378e+01,  Loss_bcs: 0.000e+00, Loss_ut_ics: 5.056e-03, Loss_norm: 2.916e-02, Loss_gauge: 0.000e+00, w_pde: 6.67e-01, L^2_error: 8.930e-01, lr: 1.000e-03, Time: 4.72e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2026-02-03_15-23-49-172771_box_DV\model.pth
# INFO:src.utils.logger:Model weights saved to ./results/models/checkpoints/smoke_schrodinger\2026-02-03_15-23-49-172771_box_DV\model_weights.pth
# INFO:src.utils.logger:It: 150, Loss: 2.288e+01, Loss_res: 2.099e+01,  Loss_bcs: 0.000e+00, Loss_ut_ics: 6.593e-03, Loss_norm: 4.675e-02, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 8.653e-01, lr: 1.000e-03, Time: 7.01e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2026-02-03_15-23-49-172771_box_DV\model.pth
# INFO:src.utils.logger:Model weights saved to ./results/models/checkpoints/smoke_schrodinger\2026-02-03_15-23-49-172771_box_DV\model_weights.pth
# INFO:src.utils.logger:It: 200, Loss: 2.168e+01, Loss_res: 1.972e+01,  Loss_bcs: 0.000e+00, Loss_ut_ics: 6.792e-03, Loss_norm: 5.111e-02, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 8.504e-01, lr: 1.000e-03, Time: 9.08e+02
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2026-02-03_15-23-49-172771_box_DV\model.pth
# INFO:src.utils.logger:Model weights saved to ./results/models/checkpoints/smoke_schrodinger\2026-02-03_15-23-49-172771_box_DV\model_weights.pth
# INFO:src.utils.logger:It: 250, Loss: 1.966e+01, Loss_res: 1.741e+01,  Loss_bcs: 0.000e+00, Loss_ut_ics: 7.826e-03, Loss_norm: 6.000e-02, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 7.947e-01, lr: 1.000e-03, Time: 1.14e+03
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2026-02-03_15-23-49-172771_box_DV\model.pth
# INFO:src.utils.logger:Model weights saved to ./results/models/checkpoints/smoke_schrodinger\2026-02-03_15-23-49-172771_box_DV\model_weights.pth
# INFO:src.utils.logger:It: 300, Loss: 4.433e+00, Loss_res: 4.268e+00,  Loss_bcs: 0.000e+00, Loss_ut_ics: 4.080e-04, Loss_norm: 1.255e-02, Loss_gauge: 0.000e+00, w_pde: 1.00e+00, L^2_error: 2.522e-01, lr: 1.000e-03, Time: 1.37e+03
# INFO:src.utils.logger:Model state saved to ./results/models/checkpoints/smoke_schrodinger\2026-02-03_15-23-49-172771_box_DV\model.pth
# INFO:src.utils.logger:Model weights saved to ./results/models/checkpoints/smoke_schrodinger\2026-02-03_15-23-49-172771_box_DV\model_weights.pth
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 # tamaños recomendados para DV (no tan grandes al inicio)
# ----> 2 train(model, N_f=768, N_b=0, N_0=256)
#
# File ~\Documents\A master\Tesis\QPINNs-2025\src\trainer\schrodinger_train.py:253, in train(model, N_f, N_b, N_0)
#     251 ti = t_f[i0:i0 + pde_chunk_size]
#     252 xi = x_f[i0:i0 + pde_chunk_size]
# --> 253 _, _, rR, rI = schrodinger_operator(
#     254     model, ti, xi,
#     255     potential_fn=problem["potential_fn"],
#     256     mass=problem["mass"],
#     257     hbar=problem["hbar"],
#     258 )
#     259 loss_i = mse(rR, torch.zeros_like(rR)) + w_pde_i * mse(rI, torch.zeros_like(rI))
#     260 loss_chunks.append(loss_i)
#
# File ~\Documents\A master\Tesis\QPINNs-2025\src\nn\pde.py:108, in schrodinger_operator(model, t, x, potential_fn, mass, hbar)
#     105 t = t.requires_grad_(True)
#     106 x = x.requires_grad_(True)
# --> 108 psi = model(torch.cat((t, x), dim=1))
#     109 psi_r = psi[:, 0:1]
#     110 psi_i = psi[:, 1:2]
#
# File c:\conda\envs\qml-2025\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\conda\envs\qml-2025\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~\Documents\A master\Tesis\QPINNs-2025\src\nn\DVPDESolver.py:198, in DVPDESolver.forward(self, tx)
#     195     self.draw_quantum_circuit(pre)
#     196     self.draw_quantum_circuit_flag = False
# --> 198 q_out = self.quantum_layer(pre).to(self.device, dtype=pre.dtype)
#     199 out = self.postprocessor(q_out)
#     201 # 1) aplica fase global (si está activa)
#
# File c:\conda\envs\qml-2025\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\conda\envs\qml-2025\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~\Documents\A master\Tesis\QPINNs-2025\src\nn\DVQuantumLayer.py:149, in DVQuantumLayer.forward(self, x)
#     147 if self.dv_batching_mode == "broadcast" and (self._broadcast_ok is not False):
#     148     try:
# --> 149         res = self.circuit(x)  # <-- batcheo por broadcasting
#     151         # res suele ser list/tuple de largo num_qubits, cada item shape (B,)
#     152         if isinstance(res, (list, tuple)):
#
# File c:\conda\envs\qml-2025\Lib\site-packages\pennylane\workflow\qnode.py:922, in QNode.__call__(self, *args, **kwargs)
#     919     from ._capture_qnode import capture_qnode  # pylint: disable=import-outside-toplevel
#     921     return capture_qnode(self, *args, **kwargs)
# --> 922 return self._impl_call(*args, **kwargs)
#
# File c:\conda\envs\qml-2025\Lib\site-packages\pennylane\workflow\qnode.py:895, in QNode._impl_call(self, *args, **kwargs)
#     892 # Calculate the classical jacobians if necessary
#     893 self._transform_program.set_classical_component(self, args, kwargs)
# --> 895 res = execute(
#     896     (tape,),
#     897     device=self.device,
#     898     diff_method=self.diff_method,
#     899     interface=self.interface,
#     900     transform_program=self._transform_program,
#     901     gradient_kwargs=self.gradient_kwargs,
#     902     **self.execute_kwargs,
#     903 )
#     904 res = res[0]
#     906 # convert result to the interface in case the qfunc has no parameters
#
# File c:\conda\envs\qml-2025\Lib\site-packages\pennylane\workflow\execution.py:229, in execute(tapes, device, diff_method, interface, grad_on_execution, cache, cachesize, max_diff, device_vjp, postselect_mode, mcm_method, gradient_kwargs, transform_program, executor_backend)
#     226 outer_transform, inner_transform = _setup_transform_program(device, config, cache, cachesize)
#     228 #### Executing the configured setup #####
# --> 229 tapes, outer_post_processing = outer_transform(tapes)
#     231 assert not outer_transform.is_informative, "should only contain device preprocessing"
#     233 results = run(tapes, device, config, inner_transform)
#
# File c:\conda\envs\qml-2025\Lib\site-packages\pennylane\transforms\core\transform_program.py:501, in TransformProgram.__call__(self, *args, **kwargs)
#     499 if type(args[0]).__name__ == "Jaxpr":
#     500     return self.__call_jaxpr(*args, **kwargs)
# --> 501 return self.__call_tapes(*args, **kwargs)
#
# File c:\conda\envs\qml-2025\Lib\site-packages\pennylane\transforms\core\transform_program.py:431, in TransformProgram.__call_tapes(self, tapes)
#     428 if argnums is not None:
#     429     # pylint: disable=unsubscriptable-object
#     430     tape.trainable_params = argnums[tape_idx]
# --> 431 new_tapes, fn = transform(tape, *targs, **tkwargs)
#     432 execution_tapes.extend(new_tapes)
#     434 fns.append(fn)
#
# File c:\conda\envs\qml-2025\Lib\site-packages\pennylane\devices\preprocess.py:404, in decompose(tape, stopping_condition, stopping_condition_shots, skip_initial_state_prep, decomposer, name, error)
#     401     return (tape,), null_postprocessing
#     402 try:
# --> 404     new_ops = [
#     405         final_op
#     406         for op in tape.operations[len(prep_op) :]
#     407         for final_op in _operator_decomposition_gen(
#     408             op,
#     409             stopping_condition,
#     410             decomposer=decomposer,
#     411             name=name,
#     412             error=error,
#     413         )
#     414     ]
#     415 except RecursionError as e:
#     416     raise error(
#     417         "Reached recursion limit trying to decompose operations. "
#     418         "Operator decomposition may have entered an infinite loop."
#     419     ) from e
#
# File c:\conda\envs\qml-2025\Lib\site-packages\pennylane\devices\preprocess.py:404, in <listcomp>(.0)
#     401     return (tape,), null_postprocessing
#     402 try:
# --> 404     new_ops = [
#     405         final_op
#     406         for op in tape.operations[len(prep_op) :]
#     407         for final_op in _operator_decomposition_gen(
#     408             op,
#     409             stopping_condition,
#     410             decomposer=decomposer,
#     411             name=name,
#     412             error=error,
#     413         )
#     414     ]
#     415 except RecursionError as e:
#     416     raise error(
#     417         "Reached recursion limit trying to decompose operations. "
#     418         "Operator decomposition may have entered an infinite loop."
#     419     ) from e
#
# File c:\conda\envs\qml-2025\Lib\site-packages\pennylane\devices\preprocess.py:66, in _operator_decomposition_gen(op, acceptance_function, decomposer, max_expansion, current_depth, name, error)
#      64 else:
#      65     try:
# ---> 66         decomp = decomposer(op)
#      67         current_depth += 1
#      68     except qml.operation.DecompositionUndefinedError as e:
#
# File c:\conda\envs\qml-2025\Lib\site-packages\pennylane\devices\preprocess.py:390, in decompose.<locals>.decomposer(op)
#     389 def decomposer(op):
# --> 390     return op.decomposition()
#
# File c:\conda\envs\qml-2025\Lib\site-packages\pennylane\operation.py:1435, in Operator.decomposition(self)
#    1423 def decomposition(self) -> list["Operator"]:
#    1424     r"""Representation of the operator as a product of other operators.
#    1425
#    1426     .. math:: O = O_1 O_2 \dots O_n
#    (...)   1433         list[Operator]: decomposition of the operator
#    1434     """
# -> 1435     return self.compute_decomposition(
#    1436         *self.parameters, wires=self.wires, **self.hyperparameters
#    1437     )
#
# File c:\conda\envs\qml-2025\Lib\site-packages\pennylane\templates\embeddings\angle.py:138, in AngleEmbedding.compute_decomposition(features, wires, rotation)
#     135 batched = math.ndim(features) > 1
#     136 # We will iterate over the first axis of `features` together with iterating over the wires.
#     137 # If the leading dimension is a batch dimension, exchange the wire and batching axes.
# --> 138 features = math.T(features) if batched else features
#     140 return [rotation(features[i], wires=wires[i]) for i in range(len(wires))]
#
# File c:\conda\envs\qml-2025\Lib\site-packages\autoray\autoray.py:81, in do(fn, like, *args, **kwargs)
#      79 backend = _choose_backend(fn, args, kwargs, like=like)
#      80 func = get_lib_fn(backend, fn)
# ---> 81 return func(*args, **kwargs)
#
# File c:\conda\envs\qml-2025\Lib\site-packages\autoray\autoray.py:1919, in torch_transpose(x, axes)
#    1917 if axes is None:
#    1918     axes = reversed(range(0, x.ndimension()))
# -> 1919 return x.permute(*axes)
#
# KeyboardInterrupt:

# %%
def count_trainable_params(m):
    total = sum(p.numel() for p in m.parameters() if p.requires_grad)
    quantum = sum(p.numel() for n, p in m.named_parameters() if ("quantum_layer" in n) and p.requires_grad)
    classical = total - quantum
    return total, quantum, classical

tot, q, c = count_trainable_params(model)
print(f"Trainable params -> total: {tot} | quantum: {q} | classical: {c}")
# Out:
# Trainable params -> total: 918 | quantum: 16 | classical: 902

# %%
import torch

device_ = next(model.parameters()).device
dtype_  = next(model.parameters()).dtype
problem = build_problem(eq_params, device=device_, dtype=dtype_)

# grid en x y tiempos
x = torch.linspace(problem["x_min"], problem["x_max"], 400, device=device_, dtype=dtype_).reshape(-1,1)
t0 = torch.zeros_like(x)
tT = torch.full_like(x, float(problem["T"]))

with torch.no_grad():
    psi0 = model(torch.cat([t0, x], dim=1))
    psiT = model(torch.cat([tT, x], dim=1))

# norma (trapz)
prob0 = psi0[:,0]**2 + psi0[:,1]**2
probT = psiT[:,0]**2 + psiT[:,1]**2
norm0 = torch.trapz(prob0, x.squeeze(-1)).item()
normT = torch.trapz(probT, x.squeeze(-1)).item()

# BC: valores en bordes
xL = torch.tensor([[problem["x_min"]],[problem["x_max"]]], device=device_, dtype=dtype_)
tline = torch.linspace(0.0, float(problem["T"]), 200, device=device_, dtype=dtype_).reshape(-1,1)

with torch.no_grad():
    psi_left  = model(torch.cat([tline, torch.full_like(tline, float(problem["x_min"]))], dim=1))
    psi_right = model(torch.cat([tline, torch.full_like(tline, float(problem["x_max"]))], dim=1))

max_left  = torch.sqrt(psi_left[:,0]**2  + psi_left[:,1]**2).max().item()
max_right = torch.sqrt(psi_right[:,0]**2 + psi_right[:,1]**2).max().item()

print("Norm pred t=0:", norm0)
print("Norm pred t=T:", normT)
print("max |psi(t,x_min)|:", max_left)
print("max |psi(t,x_max)|:", max_right)
# Out:
# Norm pred t=0: 0.9961315393447876
# Norm pred t=T: 0.992874264717102
# max |psi(t,x_min)|: 0.0
# max |psi(t,x_max)|: 0.0

# %%
import numpy as np

x_plot = torch.linspace(problem["x_min"], problem["x_max"], 500, device=device_, dtype=dtype_).reshape(-1,1)
t0p = torch.zeros_like(x_plot)
tTp = torch.full_like(x_plot, float(problem["T"]))

with torch.no_grad():
    re0_ex, im0_ex, _ = problem["exact"](problem["n_level"], t0p, x_plot)
    reT_ex, imT_ex, _ = problem["exact"](problem["n_level"], tTp, x_plot)

    y0 = model(torch.cat([t0p, x_plot], dim=1))
    yT = model(torch.cat([tTp, x_plot], dim=1))

re0_pr, im0_pr = y0[:,0:1], y0[:,1:2]
reT_pr, imT_pr = yT[:,0:1], yT[:,1:2]

p0_ex = (re0_ex**2 + im0_ex**2).detach().cpu().numpy().squeeze()
p0_pr = (re0_pr**2 + im0_pr**2).detach().cpu().numpy().squeeze()
pT_ex = (reT_ex**2 + imT_ex**2).detach().cpu().numpy().squeeze()
pT_pr = (reT_pr**2 + imT_pr**2).detach().cpu().numpy().squeeze()

xx = x_plot.detach().cpu().numpy().squeeze()

plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.plot(xx, p0_ex, label="Exact")
plt.plot(xx, p0_pr, "--", label="Pred")
plt.title("|psi(x,0)|^2")
plt.xlabel("x"); plt.ylabel("|psi|^2"); plt.legend()

plt.subplot(1,2,2)
plt.plot(xx, pT_ex, label="Exact")
plt.plot(xx, pT_pr, "--", label="Pred")
plt.title(f"|psi(x,T)|^2  (T={problem['T']})")
plt.xlabel("x"); plt.ylabel("|psi|^2"); plt.legend()

plt.tight_layout()
plt.show()

# %%
import numpy as np

loss_hist = np.array(getattr(model, "loss_history", []), dtype=float)
l2_hist   = np.array(getattr(model, "l2_rel_history", []), dtype=float)

plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.plot(loss_hist)
plt.yscale("log")
plt.title("Loss vs epochs")
plt.xlabel("epoch"); plt.ylabel("loss")

plt.subplot(1,2,2)
plt.plot(l2_hist)
plt.yscale("log")
plt.title("L2 relative error vs epochs")
plt.xlabel("epoch"); plt.ylabel("L2_rel")

plt.tight_layout()
plt.show()

# %%
import numpy as np

Nt, Nx = 80, 220
t_grid = torch.linspace(0.0, float(problem["T"]), Nt, device=device_, dtype=dtype_).reshape(-1,1)
x_grid = torch.linspace(problem["x_min"], problem["x_max"], Nx, device=device_, dtype=dtype_).reshape(-1,1)

# mallado tipo (Nt*Nx, 1)
TT = t_grid.repeat(1, Nx).reshape(-1,1)
XX = x_grid.repeat(Nt, 1)

with torch.no_grad():
    re_ex, im_ex, _ = problem["exact"](problem["n_level"], TT, XX)
    y_pr = model(torch.cat([TT, XX], dim=1))
    re_pr, im_pr = y_pr[:,0:1], y_pr[:,1:2]

re_ex = re_ex.reshape(Nt, Nx).detach().cpu().numpy()
im_ex = im_ex.reshape(Nt, Nx).detach().cpu().numpy()
re_pr = re_pr.reshape(Nt, Nx).detach().cpu().numpy()
im_pr = im_pr.reshape(Nt, Nx).detach().cpu().numpy()

re_er = re_pr - re_ex
im_er = im_pr - im_ex

extent = [float(problem["x_min"]), float(problem["x_max"]), float(problem["T"]), 0.0]

plt.figure(figsize=(12,8))

plt.subplot(3,2,1); plt.imshow(re_ex, aspect="auto", extent=extent); plt.title("Re exact"); plt.ylabel("t"); plt.colorbar()
plt.subplot(3,2,2); plt.imshow(re_pr, aspect="auto", extent=extent); plt.title("Re pred");  plt.colorbar()

plt.subplot(3,2,3); plt.imshow(im_ex, aspect="auto", extent=extent); plt.title("Im exact"); plt.ylabel("t"); plt.colorbar()
plt.subplot(3,2,4); plt.imshow(im_pr, aspect="auto", extent=extent); plt.title("Im pred");  plt.colorbar()

plt.subplot(3,2,5); plt.imshow(re_er, aspect="auto", extent=extent); plt.title("Re error"); plt.xlabel("x"); plt.ylabel("t"); plt.colorbar()
plt.subplot(3,2,6); plt.imshow(im_er, aspect="auto", extent=extent); plt.title("Im error"); plt.xlabel("x"); plt.colorbar()

plt.tight_layout()
plt.show()
